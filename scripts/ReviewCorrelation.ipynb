# %%
import os
import scipy
import numpy as np
import pandas as pd
import seaborn as sns
from pprint import pprint
import matplotlib.pyplot as plt

# %%
def dicoGrpSp():
    dicoSp = {'pan_troglodytes' : 'Eukaryote',
    'homo_sapiens' : 'Eukaryote',
    'pongo_abelii' : 'Eukaryote',
    'mus_musculus' : 'Eukaryote',
    'monodelphis_domestica' : 'Eukaryote',
    'ornithorhynchus_anatinus' : 'Eukaryote',
    'anolis_carolinensis' : 'Eukaryote',
    'gallus_gallus' : 'Eukaryote',
    'danio_rerio' : 'Eukaryote',
    'gasterosteus_aculeatus' : 'Eukaryote',
    'drosophila_melanogaster' : 'Eukaryote',
    'apis_mellifera' : 'Eukaryote',
    'caenorhabditis_elegans' : 'Eukaryote',
    'neurospora_crassa' : 'Eukaryote',
    'aspergillus_nidulans' : 'Eukaryote',
    'saccharomyces_cerevisiae' : 'Eukaryote',
    'schizosaccharomyces_pombe' : 'Eukaryote',
    'dictyostelium_discoideum' : 'Eukaryote',
    'arabidopsis_thaliana' : 'Eukaryote',
    'vitis_vinifera' : 'Eukaryote',
    'solanum_lycopersicum' : 'Eukaryote',
    'oryza_sativa' : 'Eukaryote',
    'physcomitrella_patens' : 'Eukaryote',
    'chlamydomonas_reinhardtii' : 'Eukaryote',
    'leishmania_major' : 'Eukaryote',
    'methanosarcina_acetivorans_c2a' : 'Archaea',
    'halobacterium_salinarum_r1' : 'Archaea',
    'hyperthermus_butylicus_dsm_5456' : 'Archaea',
    'archaeoglobus_fulgidus_dsm_4304' : 'Archaea',
    'methanobrevibacter_smithii_atcc_35061' : 'Archaea',
    'pyrococcus_horikoshii_ot3' : 'Archaea',
    'thermoplasma_acidophilum_dsm_1728' : 'Archaea',
    'sulfolobus_solfataricus_p2' : 'Archaea',
    'pyrobaculum_aerophilum_str_im2' : 'Archaea',
    'nanoarchaeum_equitans_kin4_m' : 'Archaea',
    'candidatus_korarchaeum_cryptofilum_opf8' : 'Archaea',
    'cenarchaeum_symbiosum_a' : 'Archaea',
    'aquifex_aeolicus_vf5' : 'Bacteria',
    'mycoplasma_pneumoniae_m129' : 'Bacteria',
    'staphylococcus_aureus_subsp_aureus_n315' : 'Bacteria',
    'bacillus_subtilis_subsp_subtilis_str_168' : 'Bacteria',
    'enterococcus_faecalis_v583' : 'Bacteria',
    'streptococcus_pneumoniae_tigr4' : 'Bacteria',
    'chloroflexus_aurantiacus_j_10_fl' : 'Bacteria',
    'mycobacterium_tuberculosis_h37rv' : 'Bacteria',
    'thermus_thermophilus_hb8' : 'Bacteria',
    'chlamydia_trachomatis_d_uw_3_cx' : 'Bacteria',
    'borrelia_burgdorferi_b31' : 'Bacteria',
    'campylobacter_jejuni_subsp_jejuni_nctc_11168_atcc_700819' : 'Bacteria',
    'myxococcus_xanthus_dk_1622' : 'Bacteria',
    'geobacter_sulfurreducens_pca' : 'Bacteria',
    'wolbachia_endosymbiont_of_drosophila_melanogaster' : 'Bacteria',
    'anaplasma_phagocytophilum_str_hz' : 'Bacteria',
    'brucella_abortus_bv_1_str_9_941' : 'Bacteria',
    'neisseria_meningitidis_z2491' : 'Bacteria',
    'legionella_pneumophila_str_paris' : 'Bacteria',
    'francisella_tularensis_subsp_tularensis_schu_s4' : 'Bacteria',
    'vibrio_cholerae_o1_biovar_el_tor_str_n16961' : 'Bacteria',
    'haemophilus_influenzae_rd_kw20' : 'Bacteria',
    'yersinia_pestis_biovar_microtus_str_91001' : 'Bacteria',
    'escherichia_coli_str_k_12_substr_mg1655' : 'Bacteria'}
    return dicoSp

# %%
def getShortName():
    dicoSp = {'pan_troglodytes' : 'Ptro',
    'homo_sapiens' : 'Hsap',
    'pongo_abelii' : 'Pabe',
    'mus_musculus' : 'Mmus',
    'monodelphis_domestica' : 'Mdom',
    'ornithorhynchus_anatinus' : 'Oana',
    'anolis_carolinensis' : 'Acar',
    'gallus_gallus' : 'Ggal',
    'danio_rerio' : 'Drer',
    'gasterosteus_aculeatus' : 'Gacu',
    'drosophila_melanogaster' : 'Dmel',
    'apis_mellifera' : 'Amel',
    'caenorhabditis_elegans' : 'Cele',
    'neurospora_crassa' : 'Ncra',
    'aspergillus_nidulans' : 'Anid',
    'saccharomyces_cerevisiae' : 'Scer',
    'schizosaccharomyces_pombe' : 'Spom',
    'dictyostelium_discoideum' : 'Ddis',
    'arabidopsis_thaliana' : 'Atha',
    'vitis_vinifera' : 'Vvin',
    'solanum_lycopersicum' : 'Slyc',
    'oryza_sativa' : 'Osat',
    'physcomitrella_patens' : 'Ppat',
    'chlamydomonas_reinhardtii' : 'Crei',
    'leishmania_major' : 'Lmaj',
    'methanosarcina_acetivorans_c2a' : 'Mace',
    'halobacterium_salinarum_r1' : 'Hsal',
    'hyperthermus_butylicus_dsm_5456' : 'Hbut',
    'archaeoglobus_fulgidus_dsm_4304' : 'Aful',
    'methanobrevibacter_smithii_atcc_35061' : 'Msmi',
    'pyrococcus_horikoshii_ot3' : 'Phor',
    'thermoplasma_acidophilum_dsm_1728' : 'Taci',
    'sulfolobus_solfataricus_p2' : 'Ssol',
    'pyrobaculum_aerophilum_str_im2' : 'Paer',
    'nanoarchaeum_equitans_kin4_m' : 'Nequ',
    'candidatus_korarchaeum_cryptofilum_opf8' : 'Ckor',
    'cenarchaeum_symbiosum_a' : 'Csym',
    'aquifex_aeolicus_vf5' : 'Aaeo',
    'mycoplasma_pneumoniae_m129' : 'Mpne',
    'staphylococcus_aureus_subsp_aureus_n315' : 'Saur',
    'bacillus_subtilis_subsp_subtilis_str_168' : 'Bsub',
    'enterococcus_faecalis_v583' : 'Efae',
    'streptococcus_pneumoniae_tigr4' : 'Spne',
    'chloroflexus_aurantiacus_j_10_fl' : 'Caur',
    'mycobacterium_tuberculosis_h37rv' : 'Mtub',
    'thermus_thermophilus_hb8' : 'Tthe',
    'chlamydia_trachomatis_d_uw_3_cx' : 'Ctra',
    'borrelia_burgdorferi_b31' : 'Bbur',
    'campylobacter_jejuni_subsp_jejuni_nctc_11168_atcc_700819' : 'Cjej',
    'myxococcus_xanthus_dk_1622' : 'Mxan',
    'geobacter_sulfurreducens_pca' : 'Gsul',
    'wolbachia_endosymbiont_of_drosophila_melanogaster' : 'Wend',
    'anaplasma_phagocytophilum_str_hz' : 'Apha',
    'brucella_abortus_bv_1_str_9_941' : 'Babo',
    'neisseria_meningitidis_z2491' : 'Nmen',
    'legionella_pneumophila_str_paris' : 'Lpne',
    'francisella_tularensis_subsp_tularensis_schu_s4' : 'Ftul',
    'vibrio_cholerae_o1_biovar_el_tor_str_n16961' : 'Vcho',
    'haemophilus_influenzae_rd_kw20' : 'Hinf',
    'yersinia_pestis_biovar_microtus_str_91001' : 'Ypes',
    'escherichia_coli_str_k_12_substr_mg1655' : 'Ecol'}
    return dicoSp

# %%
def applyShortName(sp):
    dico = getShortName()
    return dico[sp]

# %%
def getGrp(sp):
    dico = dicoGrpSp()
    return dico[sp]

# %% [markdown]
# # Gene

# %%
path = '/home/anais/Documents/Projet/G4Conservation/'
dfGenesDens = pd.read_csv(path+'Results/GenesDensities.csv', sep='\t')
dfGenesDens['ShortName'] = dfGenesDens.Sp.apply(applyShortName)
dfGenesDens['Density'] = dfGenesDens['DensityGenes'] - dfGenesDens['meanShuflle']
dfGenesDens['DensityQuot'] = dfGenesDens['DensityGenes'] / dfGenesDens['meanShuflle']
dfGenesDens.head
# Out:
# <bound method NDFrame.head of                                                  Sp  DensityGenes         GC  \
# 0                                   pan_troglodytes      0.162269  41.411866
# 1                                      homo_sapiens      0.157128  41.431160
# 2                                      pongo_abelii      0.153484  39.989608
# 3                                      mus_musculus      0.179057  42.796644
# 4                             monodelphis_domestica      0.140690  37.785004
# ..                                              ...           ...        ...
# 56  francisella_tularensis_subsp_tularensis_schu_s4      0.001726  33.286418
# 57      vibrio_cholerae_o1_biovar_el_tor_str_n16961      0.007163  47.545797
# 58                   haemophilus_influenzae_rd_kw20      0.009210  39.270580
# 59        yersinia_pestis_biovar_microtus_str_91001      0.049307  49.022334
# 60          escherichia_coli_str_k_12_substr_mg1655      0.018923  51.859621
#
#        SpRealm  meanShuflle  stdShuffle ShortName   Density  DensityQuot
# 0   Eukaryotes     0.012451    0.000200      Ptro  0.149819    13.033074
# 1   Eukaryotes     0.010975    0.000719      Hsap  0.146153    14.317283
# 2   Eukaryotes     0.009375    0.000061      Pabe  0.144110    16.372513
# 3   Eukaryotes     0.009698    0.000091      Mmus  0.169359    18.464051
# 4   Eukaryotes     0.002878    0.000111      Mdom  0.137811    48.877783
# ..         ...          ...         ...       ...       ...          ...
# 56    Bacteria     0.005867    0.001913      Ftul -0.004141     0.294118
# 57    Bacteria     0.024907    0.000665      Vcho -0.017743     0.287611
# 58    Bacteria     0.012341    0.002412      Hinf -0.003131     0.746269
# 59    Bacteria     0.065960    0.002943      Ypes -0.016654     0.747521
# 60    Bacteria     0.091237    0.004177      Ecol -0.072314     0.207404
#
# [61 rows x 9 columns]>

# %% [markdown]
# ## First analyse (with outlier)

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfGenesDens)
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)

my_pl = {'Eukaryote':"#D3772E", 'Eukaryotes':"#D3772E", 'Archaea':"#2686a4", 'Bacteria':"#c33543"} #test1
# my_pl = {'Eukaryote':"#e9c662", 'Eukaryotes':"#e9c662", 'Archaea':"#73bca9", 'Bacteria':"#e74e46"} #test2

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="Density", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["Density"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.00712603418083539, intercept=0.2914329650347577, rvalue=-0.6529018450414102, pvalue=0.021345775211173455, stderr=0.002614265490588621, intercept_stderr=0.12605844524032223)
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.002551754349788584, intercept=0.08512299457745773, rvalue=-0.23871477165092672, pvalue=0.26128239230006234, stderr=0.0022131333832427513, intercept_stderr=0.10630263194992383)
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.006021417006490613, intercept=-0.1509037236761374, rvalue=0.38518487475350716, pvalue=0.05724470032479084, stderr=0.0030080960794197967, intercept_stderr=0.1292397190249966)

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfGenesDens)
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)

my_pl = {'Eukaryote':"#D3772E", 'Eukaryotes':"#D3772E", 'Archaea':"#2686a4", 'Bacteria':"#c33543"} #test1
# my_pl = {'Eukaryote':"#e9c662", 'Eukaryotes':"#e9c662", 'Archaea':"#73bca9", 'Bacteria':"#e74e46"} #test2

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DensityQuot", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DensityQuot"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.011202938775399959, intercept=1.2834490708239574, rvalue=-0.23484147893428728, pvalue=0.46251275088087995, stderr=0.014663527904079068, intercept_stderr=0.7070672569334545)
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.015077953570408366, intercept=1.496856425669694, rvalue=-0.165649339738035, pvalue=0.4391919501421476, stderr=0.01913813527778764, intercept_stderr=0.9192551005044247)
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.6894001778510984, intercept=43.48946476655653, rvalue=-0.4229056567160467, pvalue=0.03518241896819241, stderr=0.30801753465753234, intercept_stderr=13.233652976134271)

# %% [markdown]
# ## Check outlier with boxplot
#
# We are going to use the IQR method (Interquartile Range), to visualise outlier and remove them.

# %%
groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print(name1)
    sns.boxplot(y="Density", data=group1)
    plt.show()
# Out:
# Archaea
# Bacteria
# Eukaryote

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.Density,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    print(min, max)
    
    print(group1[group1.Density < min])
    print(group1[group1.Density > max])
# Out:
# -------------Archaea----------------
# -0.2466387401075 0.1627467855125
#                             Sp  DensityGenes         GC  SpRealm  meanShuflle  \
# 26  halobacterium_salinarum_r1      0.086868  66.422559  Archaea     0.378966
#
#     stdShuffle ShortName   Density    Group
# 26    0.008951      Hsal -0.292098  Archaea
# Empty DataFrame
# Columns: [Sp, DensityGenes, GC, SpRealm, meanShuflle, stdShuffle, ShortName, Density, Group]
# Index: []
# -------------Bacteria----------------
# -0.163186590584 0.09168987978
#                                   Sp  DensityGenes         GC   SpRealm  \
# 44  mycobacterium_tuberculosis_h37rv      0.140327  65.918814  Bacteria
# 49        myxococcus_xanthus_dk_1622      0.190722  69.094395  Bacteria
#
#     meanShuflle  stdShuffle ShortName   Density     Group
# 44     0.430635    0.006999      Mtub -0.290307  Bacteria
# 49     0.561457    0.005637      Mxan -0.370735  Bacteria
#                           Sp  DensityGenes         GC   SpRealm  meanShuflle  \
# 45  thermus_thermophilus_hb8      0.774935  69.611518  Bacteria      0.40569
#
#     stdShuffle ShortName   Density     Group
# 45    0.011889      Tthe  0.369245  Bacteria
# -------------Eukaryote----------------
# -0.14032655142750003 0.3180413713365
#                   Sp  DensityGenes         GC     SpRealm  meanShuflle  \
# 24  leishmania_major      0.074079  62.395859  Eukaryotes     0.238899
#
#     stdShuffle ShortName  Density      Group
# 24    0.003053      Lmaj -0.16482  Eukaryote
#                            Sp  DensityGenes         GC     SpRealm  \
# 23  chlamydomonas_reinhardtii       1.15765  63.994546  Eukaryotes
#
#     meanShuflle  stdShuffle ShortName   Density      Group
# 23     0.565293    0.001861      Crei  0.592357  Eukaryote

# %% [markdown]
# - Eukrayotes -> 2 outlier, Crei - Lmaj
# - Bacteria -> 3 outlier, Tthe - Mtub - Mxan
# - Archaea -> 1 outlier, Hsal

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.Density,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    group1 = group1[group1.Density > min]
    group1 = group1[group1.Density < max]
    
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="Density", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/reviewCorrelation/Corr_Gene_"+name1+".svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["Density"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.004008408506118527, intercept=0.15967324433041744, rvalue=-0.4136072713217323, pvalue=0.20604917379945528, stderr=0.0029411774568267875, intercept_stderr=0.13591303523259635)
# -------------Bacteria----------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.0027083520642693145, intercept=0.09312850692660415, rvalue=-0.6575895749162484, pvalue=0.0011968803670935305, stderr=0.0007118449219308489, intercept_stderr=0.03160880472543134)
# -------------Eukaryote----------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.006193695944643878, intercept=-0.156474267607632, rvalue=0.5259935963295327, pvalue=0.009937591873974487, stderr=0.002185386406223207, intercept_stderr=0.08901492231933103)

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.Density,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    group1 = group1[group1.Density > min]
    group1 = group1[group1.Density < max]
    
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="Density", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/reviewCorrelation/Corr_Gene_"+name1+".svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["Density"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.004008408506118527, intercept=0.15967324433041744, rvalue=-0.4136072713217323, pvalue=0.20604917379945528, stderr=0.0029411774568267875, intercept_stderr=0.13591303523259635)
# -------------Bacteria----------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.0027083520642693145, intercept=0.09312850692660415, rvalue=-0.6575895749162484, pvalue=0.0011968803670935305, stderr=0.0007118449219308489, intercept_stderr=0.03160880472543134)
# -------------Eukaryote----------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.006193695944643878, intercept=-0.156474267607632, rvalue=0.5259935963295327, pvalue=0.009937591873974487, stderr=0.002185386406223207, intercept_stderr=0.08901492231933103)

# %% [markdown]
# # Transcript global

# %% [markdown]
# ## Data upload

# %%
path = '/home/anais/Documents/Projet/G4Conservation/'
dfGlobal = pd.read_csv(path+'/Results/Global.csv', sep='\t')
dfClassCoding = pd.read_csv(path+'/Results/Coding.csv', sep='\t')
dfLocCoding = pd.read_csv(path+'/Results/CodingLocation.csv', sep='\t')
dfNonCoding = pd.read_csv(path+'/Results/NonCoding.csv', sep='\t')
dfPseudogene = pd.read_csv(path+'Results/Pseudo.csv', sep='\t')

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfGlobal[dfGlobal.Class == 'Global'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']

my_pl = {'Eukaryote':"#D3772E", 'Eukaryotes':"#D3772E", 'Archaea':"#2686a4", 'Bacteria':"#c33543"} #test1

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/"+name1+"CorrelationGlobal.svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.007193405372975561, intercept=0.2934527110009072, rvalue=-0.6433067071340288, pvalue=0.024017694785118344, stderr=0.002707218075367009, intercept_stderr=0.13053394784484687)
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.0024256980058914687, intercept=0.08141137597298528, rvalue=-0.22715607571184493, pvalue=0.28576462476753695, stderr=0.0022171589693141583, intercept_stderr=0.10649125666987416)
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.0016917930591417796, intercept=0.003426557754092341, rvalue=0.16029188614104123, pvalue=0.4440351616021069, stderr=0.002172298908974309, intercept_stderr=0.09314260713856967)

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    print(min, max)
    
    print(group1[group1.DiffDens < min])
    print(group1[group1.DiffDens > max])
# Out:
# -------------Archaea----------------
# -0.24386930158934092 0.15994159512555786
#      Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 88  Global     0.376616   0.086848  66.422998        3          620
#
#     NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  PercentShuf  ...  nbTr     nuclA   nuclC  \
# 88        164         915       211    21.052632  ...  2945  437553.0  809322
#
#      nuclG     nuclT  ShortName  meanShuffle  stdShuffle    Group  DiffDens
# 88  804446  378211.0       Hsal     0.375995    0.014959  Archaea -0.289768
#
# [1 rows x 23 columns]
# Empty DataFrame
# Columns: [Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, ShortName, meanShuffle, stdShuffle, Group, DiffDens]
# Index: []
#
# [0 rows x 23 columns]
# -------------Bacteria----------------
# -0.15240507465381217 0.08554380658327622
#      Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 97  Global     0.429730   0.140275  65.916152        3         1106
# 99  Global     0.553667   0.190583  69.094087        3         2706
#
#     NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  PercentShuf  ...  nbTr      nuclA  \
# 97        281        1737       567    26.916525  ...  4109   677766.0
# 99       1195        4654      1602    35.713343  ...  7577  1292231.0
#
#       nuclC    nuclG      nuclT  ShortName  meanShuffle  stdShuffle     Group  \
# 97  1304239  1360138   699927.0       Mtub     0.432903    0.007093  Bacteria
# 99  2839949  2967941  1305649.0       Mxan     0.556236    0.002934  Bacteria
#
#     DiffDens
# 97 -0.289456
# 99 -0.363084
#
# [2 rows x 23 columns]
#       Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 117  Global     0.398586   0.774648  69.612221        3          622
#
#      NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  PercentShuf  ...  nbTr     nuclA  \
# 117       1008         814      1582    25.544148  ...  2435  301222.0
#
#       nuclC   nuclG     nuclT  ShortName  meanShuffle  stdShuffle     Group  \
# 117  718543  703091  319359.0       Tthe     0.412882    0.009975  Bacteria
#
#      DiffDens
# 117  0.376062
#
# [1 rows x 23 columns]
# -------------Eukaryote----------------
# -0.16942365543449334 0.31070580572878914
#      Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 92  Global     0.243762   0.073944  62.395612        3         2410
#
#     NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  PercentShuf  ...   nbTr      nuclA  \
# 92        980        3946      1197    24.025521  ...  10031  3124639.0
#
#       nuclC    nuclG      nuclT  ShortName  meanShuffle  stdShuffle  \
# 92  5008439  5092094  2962716.0       Lmaj     0.240906    0.004126
#
#         Group  DiffDens
# 92  Eukaryote -0.169818
#
# [1 rows x 23 columns]
# Empty DataFrame
# Columns: [Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, ShortName, meanShuffle, stdShuffle, Group, DiffDens]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# - Eukrayotes -> 1 outlier, Lmaj
# - Bacteria -> 3 outlier, Tthe - Mtub - Mxan
# - Archaea -> 1 outlier, Hsal

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    group1 = group1[group1.DiffDens > min]
    group1 = group1[group1.DiffDens < max]
    
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/reviewCorrelation/Corr_Transcript_"+name1+".svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.00421095816684296, intercept=0.16741381842195427, rvalue=-0.4098220158115377, pvalue=0.2106495107800223, stderr=0.003124194284669363, intercept_stderr=0.14436144308237076)
# -------------Bacteria----------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.002600812959219598, intercept=0.09019104895366305, rvalue=-0.6469988392517328, pvalue=0.001524358337683739, stderr=0.0007031751779295973, intercept_stderr=0.03122208802375506)
# -------------Eukaryote----------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.006351051236506299, intercept=-0.17706799306931403, rvalue=0.6348721819072353, pvalue=0.0008601104121185003, stderr=0.0016478297559749664, intercept_stderr=0.06898997845223273)

# %% [markdown]
# # Coding transcripts

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfClassCoding[dfClassCoding.Biotype == 'protein_coding'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']

my_pl = {'Eukaryote':"#D3772E", 'Eukaryotes':"#D3772E", 'Archaea':"#2686a4", 'Bacteria':"#c33543"} #test1

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/"+name1+"CorrelationGlobal.svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.007163389160424732, intercept=0.2909192530622012, rvalue=-0.6465312785474057, pvalue=0.023094126842000167, stderr=0.0026729417349900283, intercept_stderr=0.12850321101343898)
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.002362246899414441, intercept=0.0792225005635411, rvalue=-0.2205766438413871, pvalue=0.3003229208765006, stderr=0.00222701764611345, intercept_stderr=0.1067304357961481)
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.001693721503142353, intercept=0.00335008771862233, rvalue=0.16029072951677162, pvalue=0.4440384926577824, stderr=0.002174791179367313, intercept_stderr=0.093253256148349)

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    print(min, max)
    
    print(group1[group1.DiffDens < min])
    print(group1[group1.DiffDens > max])
# Out:
# -------------Archaea----------------
# -0.24497008749483593 0.16057031050329232
#            Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  \
# 91  protein_coding  Coding     0.386796    0.08966  66.863862        3
#
#     NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...  nbTr     nuclA   nuclC  \
# 91          908        175         893       207  ...  2707  410897.0  774028
#
#      nuclG     nuclT  meanShuffle  stdShuffle  ShortName    Group  DiffDens
# 91  769664  354120.0     0.388224    0.016229       Hsal  Archaea -0.297136
#
# [1 rows x 24 columns]
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, meanShuffle, stdShuffle, ShortName, Group, DiffDens]
# Index: []
#
# [0 rows x 24 columns]
# -------------Bacteria----------------
# -0.15452363115961057 0.08850673691072845
#             Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  \
# 100  protein_coding  Coding     0.428506   0.138196  65.932531        3
# 102  protein_coding  Coding     0.556553   0.191741  69.164211        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...  nbTr      nuclA  \
# 100         1719        300        1724       556  ...  4018   674151.0
# 102         3826       1279        4650      1602  ...  7331  1281502.0
#
#        nuclC    nuclG      nuclT  meanShuffle  stdShuffle  ShortName  \
# 100  1298856  1353793   696478.0     0.431546    0.006843       Mtub
# 102  2825308  2953366  1294830.0     0.558658    0.002625       Mxan
#
#         Group  DiffDens
# 100  Bacteria -0.290311
# 102  Bacteria -0.364811
#
# [2 rows x 24 columns]
#             Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  \
# 120  protein_coding  Coding     0.398602   0.785246  69.708796        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...  nbTr     nuclA  \
# 120         1016       1059         800      1576  ...  2238  295103.0
#
#       nuclC   nuclG     nuclT  meanShuffle  stdShuffle  ShortName     Group  \
# 120  706692  692374  312842.0     0.415648    0.011865       Tthe  Bacteria
#
#      DiffDens
# 120  0.386644
#
# [1 rows x 24 columns]
# -------------Eukaryote----------------
# -0.1694869041966995 0.3108225066414765
#            Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  \
# 95  protein_coding  Coding     0.241818   0.072163  62.468798        3
#
#     NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...  nbTr      nuclA  \
# 95         3597        972        3800      1134  ...  8315  3029798.0
#
#       nuclC    nuclG      nuclT  meanShuffle  stdShuffle  ShortName  \
# 95  4869112  4947436  2867974.0     0.238044    0.004357       Lmaj
#
#         Group  DiffDens
# 95  Eukaryote -0.169654
#
# [1 rows x 24 columns]
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, meanShuffle, stdShuffle, ShortName, Group, DiffDens]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# - Eukrayotes -> 1 outlier, Lmaj
# - Bacteria -> 3 outlier, Tthe - Mtub - Mxan
# - Archaea -> 1 outlier, Hsal

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    group1 = group1[group1.DiffDens > min]
    group1 = group1[group1.DiffDens < max]
    
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/reviewCorrelation/Corr_Coding_"+name1+".svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.004112732546290351, intercept=0.16289444434067946, rvalue=-0.4073573301505278, pvalue=0.21367740362673357, stderr=0.0030734936910097694, intercept_stderr=0.14134533882172073)
# -------------Bacteria----------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.002581705912564568, intercept=0.08979764371133331, rvalue=-0.6440887072268058, pvalue=0.0016265636814176215, stderr=0.0007034249871222002, intercept_stderr=0.031132064074624457)
# -------------Eukaryote----------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.006361151521473588, intercept=-0.1774628290599356, rvalue=0.6336546265876492, pvalue=0.0008863297277250736, stderr=0.0016557595515439573, intercept_stderr=0.06931752301711437)

# %% [markdown]
# # Coding location

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfLocCoding[dfLocCoding.Biotype == 'protein_coding'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']
# print(dfTmp.head())

my_pl = {'Eukaryote':"#D3772E", 'Eukaryotes':"#D3772E", 'Archaea':"#2686a4", 'Bacteria':"#c33543"} #test1

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    groupsLoc = group1.groupby('Location')
    for name2, group2 in groupsLoc:
        print(name1, name2)
        print("Correlation between pG4 Densities and GC content for "+name1)
        sns.regplot(x="GC", y="DiffDens", data=group2, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
#         plt.savefig("FiguresArticle/"+name1+"CorrelationLocation"+name2+".svg")
        plt.show()
        GC = np.array(group2["GC"])
        DensityGenes = np.array(group2["DiffDens"])
        corr1 = scipy.stats.linregress(GC, DensityGenes)
        print (corr1)
# Out:
# Archaea CDS
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.006923682628430057, intercept=0.2797332300307507, rvalue=-0.6329601476299113, pvalue=0.027162321518155046, stderr=0.0026779668032355123, intercept_stderr=0.1289601412031521)
# Archaea exon
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.007163389160424732, intercept=0.2909192530622012, rvalue=-0.6465312785474057, pvalue=0.023094126842000167, stderr=0.0026729417349900283, intercept_stderr=0.12850321101343898)
# Archaea start_codon
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.004111608947424822, intercept=0.09504471904236673, rvalue=-0.5378346098656496, pvalue=0.07128725407359873, stderr=0.0020380582001697863, intercept_stderr=0.09317808543129881)
# Archaea stop_codon
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.00917843624831034, intercept=0.24614081361329587, rvalue=-0.485904483264791, pvalue=0.10924650722218686, stderr=0.0052207770144002165, intercept_stderr=0.23673426130890093)
# Bacteria CDS
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.0023869248056604033, intercept=0.07961166904256085, rvalue=-0.227413330223084, pvalue=0.28520457162149504, stderr=0.002179116767581457, intercept_stderr=0.10461223694778186)
# Bacteria acceptor
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0, intercept=0.0, rvalue=0.0, pvalue=1.0, stderr=0.0, intercept_stderr=0.0)
# Bacteria donor
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0, intercept=0.0, rvalue=0.0, pvalue=1.0, stderr=0.0, intercept_stderr=0.0)
# Bacteria exon
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.0023622547214999317, intercept=0.0792226738938093, rvalue=-0.22057630147406387, pvalue=0.30032369017572547, stderr=0.0022270286538729474, intercept_stderr=0.10673108632549014)
# Bacteria intron
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0, intercept=0.0, rvalue=0.0, pvalue=1.0, stderr=0.0, intercept_stderr=0.0)
# Bacteria junction
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0, intercept=0.0, rvalue=0.0, pvalue=1.0, stderr=0.0, intercept_stderr=0.0)
# Bacteria start_codon
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.005149250568989738, intercept=0.17734557351215563, rvalue=-0.7446490678620195, pvalue=3.0031743715525878e-05, stderr=0.000984019716158907, intercept_stderr=0.042986288873308305)
# Bacteria stop_codon
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.00857646981173064, intercept=0.30910899008075404, rvalue=-0.739087815058091, pvalue=3.6989648343771974e-05, stderr=0.0016665145796128577, intercept_stderr=0.07454851851032909)
# Eukaryote CDS
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.003154792374798924, intercept=0.13810934423880927, rvalue=-0.39757665460835745, pvalue=0.049056302179981116, stderr=0.0015181850304825674, intercept_stderr=0.07560679726889616)
# Eukaryote acceptor
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-5.0254997460577225e-05, intercept=0.0013327006347213306, rvalue=-0.4334366243411556, pvalue=0.030426789691419317, stderr=2.1787290734362376e-05, intercept_stderr=0.0009395755781315739)
# Eukaryote donor
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.00010671101798028935, intercept=-0.0036596916988074547, rvalue=0.4031579461037031, pvalue=0.04568193037484891, stderr=5.050717861350078e-05, intercept_stderr=0.0022330955223632625)
# Eukaryote exon
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.0018553644763129493, intercept=0.10642184288161044, rvalue=-0.22297786365385766, pvalue=0.284001952592208, stderr=0.0016913347143805134, intercept_stderr=0.08063809717249162)
# Eukaryote five_prime_utr
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.007024143853801178, intercept=-0.25337145040797865, rvalue=0.504791280893753, pvalue=0.011878455651758836, stderr=0.0025609581791772654, intercept_stderr=0.12440493485671279)
# Eukaryote intron
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.015530180772453205, intercept=-0.4715933042338764, rvalue=0.732262323846421, pvalue=3.165344695291713e-05, stderr=0.0030116706605102794, intercept_stderr=0.11979292891715494)
# Eukaryote junction
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.00041933535648863777, intercept=0.01719677843203215, rvalue=-0.6453728965740946, pvalue=0.0004945090488478465, stderr=0.00010349156944869992, intercept_stderr=0.004974784108143581)
# Eukaryote start_codon
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.006367594776664741, intercept=0.2106324493302581, rvalue=-0.616893672628756, pvalue=0.0010214724785838174, stderr=0.0016939538614899924, intercept_stderr=0.08423767181159561)
# Eukaryote stop_codon
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.009838050870107865, intercept=0.375400790997491, rvalue=-0.5545935121927231, pvalue=0.004013683811049548, stderr=0.0030779180741026487, intercept_stderr=0.13990916975029224)
# Eukaryote three_prime_utr
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.004847839723957242, intercept=-0.11403629791602544, rvalue=0.35161605426644404, pvalue=0.10856345311510933, stderr=0.0028860732958750626, intercept_stderr=0.11650047765093556)

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    print(min, max)
    
    print(group1[group1.DiffDens < min])
    print(group1[group1.DiffDens > max])
# Out:
# -------------Archaea----------------
# -0.3655972945800201 0.21935837674801206
#             Biotype  DensityShuf  DensityWt        GC  \
# 747  protein_coding     0.949611    0.27697  45.91865
#
#                                 LocID    Location  NbLocation  NbRepro  \
# 747  stop_codon-protein_coding-Coding  stop_codon      2407.0        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  ...  nuclC  nuclG  nuclN    nuclT   Class  \
# 747           96         28  ...  16296  30125    0.0  25118.0  Coding
#
#      meanShuffle stdShuffle  ShortName    Group  DiffDens
# 747     0.801004   0.109159       Aful  Archaea -0.672641
#
# [1 rows x 32 columns]
# Empty DataFrame
# Columns: [Biotype, DensityShuf, DensityWt, GC, LocID, Location, NbLocation, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rLocShuf, NbpG4rLocWt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, Type, index, nbTr, nuclA, nuclC, nuclG, nuclN, nuclT, Class, meanShuffle, stdShuffle, ShortName, Group, DiffDens]
# Index: []
#
# [0 rows x 32 columns]
# -------------Bacteria----------------
# -0.09501623608938967 0.057009741653633796
#             Biotype  DensityShuf  DensityWt         GC  \
# 73   protein_coding     0.122409   0.019150  58.407552
# 100  protein_coding     0.430043   0.138112  66.025782
# 102  protein_coding     0.552501   0.191887  69.241054
# 324  protein_coding     0.126850   0.019458  58.305525
# 331  protein_coding     0.150227   0.052047  57.162899
# 351  protein_coding     0.428506   0.138196  65.932531
# 353  protein_coding     0.556553   0.191741  69.164211
# 653  protein_coding     0.196872   0.095453  62.666595
# 655  protein_coding     0.594345   0.354009  64.289612
# 673  protein_coding     0.915001   0.606454  64.850142
# 758  protein_coding     0.444922   0.302794  54.712469
# 778  protein_coding     0.296286   0.142217  64.131646
# 780  protein_coding     0.480672   0.172133  67.718950
# 798  protein_coding     1.627850   1.010757  66.363085
#
#                                  LocID     Location  NbLocation  NbRepro  \
# 73           CDS-protein_coding-Coding          CDS      3085.0        3
# 100          CDS-protein_coding-Coding          CDS      4018.0        3
# 102          CDS-protein_coding-Coding          CDS      7332.0        3
# 324         exon-protein_coding-Coding         exon      3085.0        3
# 331         exon-protein_coding-Coding         exon      3853.0        3
# 351         exon-protein_coding-Coding         exon      4018.0        3
# 353         exon-protein_coding-Coding         exon      7332.0        3
# 653  start_codon-protein_coding-Coding  start_codon      3991.0        3
# 655  start_codon-protein_coding-Coding  start_codon      7331.0        3
# 673  start_codon-protein_coding-Coding  start_codon      2238.0        3
# 758   stop_codon-protein_coding-Coding   stop_codon      3853.0        3
# 778   stop_codon-protein_coding-Coding   stop_codon      4018.0        3
# 780   stop_codon-protein_coding-Coding   stop_codon      7331.0        3
# 798   stop_codon-protein_coding-Coding   stop_codon      2238.0        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  ...    nuclC    nuclG  nuclN      nuclT   Class  \
# 73           291         45  ...   768835   786672    0.0   567955.0  Coding
# 100         1087        275  ...  1298019  1350423    0.0   692216.0  Coding
# 102         2679       1194  ...  2823698  2946168    0.0  1287220.0  Coding
# 324          294         46  ...   769309   788877    0.0   571353.0  Coding
# 331          517        197  ...  1178882  1237352    0.0   961890.0  Coding
# 351         1101        277  ...  1298856  1353793    0.0   696478.0  Coding
# 353         2702       1195  ...  2825308  2953366    0.0  1294830.0  Coding
# 653           33         16  ...    50916    54127    0.0    32168.0  Coding
# 655          183        109  ...    99644    98305    0.0    58491.0  Coding
# 673           86         57  ...    30039    30913    0.0    17959.0  Coding
# 758           72         49  ...    38861    49678    0.0    36866.0  Coding
# 778           50         24  ...    52111    56115    0.0    29264.0  Coding
# 780          148         53  ...   101113   107395    0.0    48146.0  Coding
# 798          153         95  ...    28655    33719    0.0    16207.0  Coding
#
#      meanShuffle stdShuffle  ShortName     Group  DiffDens
# 73      0.126526   0.006289       Babo  Bacteria -0.103259
# 100     0.430524   0.002165       Mtub  Bacteria -0.291931
# 102     0.559149   0.007191       Mxan  Bacteria -0.360614
# 324     0.130839   0.008026       Babo  Bacteria -0.107392
# 331     0.149244   0.003292       Caur  Bacteria -0.098180
# 351     0.431546   0.006843       Mtub  Bacteria -0.290311
# 353     0.558658   0.002625       Mxan  Bacteria -0.364811
# 653     0.229226   0.031909       Mtub  Bacteria -0.101419
# 655     0.599458   0.018478       Mxan  Bacteria -0.240336
# 673     0.823500   0.058533       Tthe  Bacteria -0.308547
# 758     0.490852   0.045334       Caur  Bacteria -0.142128
# 778     0.300930   0.006311       Mtub  Bacteria -0.154069
# 780     0.457794   0.017071       Mxan  Bacteria -0.308540
# 798     1.601721   0.013895       Tthe  Bacteria -0.617093
#
# [14 rows x 32 columns]
#             Biotype  DensityShuf  DensityWt         GC  \
# 120  protein_coding     0.413938   0.785882  69.835190
# 371  protein_coding     0.398602   0.785246  69.708796
# 756  protein_coding     0.000000   0.079898  38.819644
# 779  protein_coding     0.000000   0.069214  35.921927
#
#                                 LocID    Location  NbLocation  NbRepro  \
# 120         CDS-protein_coding-Coding         CDS      2238.0        3
# 371        exon-protein_coding-Coding        exon      2238.0        3
# 756  stop_codon-protein_coding-Coding  stop_codon       894.0        3
# 779  stop_codon-protein_coding-Coding  stop_codon       688.0        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  ...   nuclC   nuclG  nuclN     nuclT   Class  \
# 120          612        999  ...  706303  690611    4.0  310453.0  Coding
# 371          618       1002  ...  706692  692374    4.0  312842.0  Coding
# 756            0          3  ...    6819    7757    0.0   10990.0  Coding
# 779            0          2  ...    5054    5326    0.0    8084.0  Coding
#
#      meanShuffle stdShuffle  ShortName     Group  DiffDens
# 120     0.413192   0.000427       Tthe  Bacteria  0.371944
# 371     0.415648   0.011865       Tthe  Bacteria  0.386644
# 756     0.031959   0.032739       Ctra  Bacteria  0.079898
# 779     0.000000   0.000000       Mpne  Bacteria  0.069214
#
# [4 rows x 32 columns]
# -------------Eukaryote----------------
# -0.043649375322805245 0.05927188456477921
#             Biotype  DensityShuf  DensityWt         GC  \
# 79   protein_coding     0.920997   0.715876  70.195262
# 95   protein_coding     0.233039   0.072175  62.516277
# 330  protein_coding     0.876794   0.757543  65.621536
# 346  protein_coding     0.241900   0.071997  62.470165
# 618  protein_coding     0.521841   0.313905  52.178938
# 619  protein_coding     0.144955   0.094480  36.540560
# 634  protein_coding     0.096893   0.045678  46.120160
# 640  protein_coding     0.986197   0.744100  58.044436
# 641  protein_coding     0.206592   0.120693  53.362503
# 645  protein_coding     0.359365   0.229603  55.479190
# 648  protein_coding     0.237666   0.111674  60.377974
# 651  protein_coding     0.429254   0.343582  52.554418
# 652  protein_coding     0.285083   0.161728  54.766542
# 659  protein_coding     0.412157   0.255537  50.943427
# 660  protein_coding     1.122848   0.785707  60.042857
# 661  protein_coding     0.654573   0.417625  57.818106
# 662  protein_coding     0.599424   0.365484  49.643850
# 663  protein_coding     0.477556   0.304307  57.768899
# 675  protein_coding     0.308407   0.180261  45.221906
# 748  protein_coding     0.700499   0.451041  49.342589
# 757  protein_coding     2.297226   1.754076  64.028050
# 773  protein_coding     0.386565   0.120265  58.201472
# 783  protein_coding     1.408236   0.956134  50.701674
# 785  protein_coding     0.169841   0.083141  47.666448
# 787  protein_coding     0.120745   0.074981  44.383476
#
#                                  LocID     Location  NbLocation  NbRepro  \
# 79           CDS-protein_coding-Coding          CDS    166497.0        3
# 95           CDS-protein_coding-Coding          CDS      8320.0        3
# 330         exon-protein_coding-Coding         exon    166499.0        3
# 346         exon-protein_coding-Coding         exon      8320.0        3
# 618  start_codon-protein_coding-Coding  start_codon      7158.0        3
# 619  start_codon-protein_coding-Coding  start_codon     13277.0        3
# 634  start_codon-protein_coding-Coding  start_codon     38977.0        3
# 640  start_codon-protein_coding-Coding  start_codon     26719.0        3
# 641  start_codon-protein_coding-Coding  start_codon     14382.0        3
# 645  start_codon-protein_coding-Coding  start_codon     75378.0        3
# 648  start_codon-protein_coding-Coding  start_codon      8315.0        3
# 651  start_codon-protein_coding-Coding  start_codon     16765.0        3
# 652  start_codon-protein_coding-Coding  start_codon     53979.0        3
# 659  start_codon-protein_coding-Coding  start_codon      1752.0        3
# 660  start_codon-protein_coding-Coding  start_codon     33067.0        3
# 661  start_codon-protein_coding-Coding  start_codon     43738.0        3
# 662  start_codon-protein_coding-Coding  start_codon     85089.0        3
# 663  start_codon-protein_coding-Coding  start_codon     17556.0        3
# 675  start_codon-protein_coding-Coding  start_codon     26516.0        3
# 748   stop_codon-protein_coding-Coding   stop_codon      8502.0        3
# 757   stop_codon-protein_coding-Coding   stop_codon      6831.0        3
# 773   stop_codon-protein_coding-Coding   stop_codon      8315.0        3
# 783   stop_codon-protein_coding-Coding   stop_codon      5080.0        3
# 785   stop_codon-protein_coding-Coding   stop_codon     40331.0        3
# 787   stop_codon-protein_coding-Coding   stop_codon     85856.0        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  ...     nuclC     nuclG     nuclN       nuclT  \
# 79         11289       9866  ...  14308853  15511640     927.0   5965274.0
# 95          2300        922  ...   4866186   4938900       2.0   2857761.0
# 330        14956      14908  ...  19549160  22305061  449610.0  10553150.0
# 346         2347        922  ...   4867418   4946019       2.0   2866692.0
# 618          261        157  ...    122027    138947       0.0    119172.0
# 619          112         73  ...    120984    161347     217.0    231391.0
# 634          278        132  ...    615211    717568     177.0    789066.0
# 640         1772       1337  ...    485963    556980       0.0    382590.0
# 641          190        111  ...    236122    254646      55.0    211928.0
# 645         2130       1355  ...   1632593   1723655       0.0   1353084.0
# 648           83         39  ...    105232    105626       0.0     71353.0
# 651          481        385  ...    280801    308097     500.0    257800.0
# 652         1206        685  ...   1139467   1186950       0.0    970319.0
# 659           50         31  ...     29787     32014     329.0     29492.0
# 660         2741       1918  ...    712099    753615       0.0    487711.0
# 661         1710       1091  ...    713223    797212      48.0    554472.0
# 662         3934       2359  ...   1346193   1940906     464.0   1709261.0
# 663          532        339  ...    306975    336574    1499.0    236766.0
# 675          503        294  ...    345290    392263     384.0    452093.0
# 748          278        179  ...     80846    114975       0.0     98396.0
# 757         1235        943  ...    137707    206511      96.0     93073.0
# 773          135         42  ...     95063    108194       1.0     68130.0
# 783          461        313  ...     61678    104299       0.0     78210.0
# 785          525        257  ...    708325    765104       8.0    818771.0
# 787          806        499  ...   1400054   1577348     300.0   1916286.0
#
#       Class  meanShuffle stdShuffle  ShortName      Group  DiffDens
# 79   Coding     0.921368   0.003366       Crei  Eukaryote -0.205121
# 95   Coding     0.234793   0.002783       Lmaj  Eukaryote -0.160864
# 330  Coding     0.874009   0.002641       Crei  Eukaryote -0.119251
# 346  Coding     0.238125   0.004358       Lmaj  Eukaryote -0.169903
# 618  Coding     0.514707   0.008330       Acar  Eukaryote -0.207937
# 619  Coding     0.146652   0.011491       Amel  Eukaryote -0.050476
# 634  Coding     0.097767   0.003880       Drer  Eukaryote -0.051215
# 640  Coding     0.968000   0.011416       Ggal  Eukaryote -0.242097
# 641  Coding     0.213668   0.015399       Gacu  Eukaryote -0.085899
# 645  Coding     0.366930   0.008387       Hsap  Eukaryote -0.129761
# 648  Coding     0.210483   0.019457       Lmaj  Eukaryote -0.125991
# 651  Coding     0.441472   0.017401       Mdom  Eukaryote -0.085672
# 652  Coding     0.287889   0.005526       Mmus  Eukaryote -0.123356
# 659  Coding     0.442070   0.029571       Oana  Eukaryote -0.156620
# 660  Coding     1.124543   0.007747       Osat  Eukaryote -0.337141
# 661  Coding     0.665553   0.016595       Ptro  Eukaryote -0.236948
# 662  Coding     0.601776   0.008616       Ppat  Eukaryote -0.233940
# 663  Coding     0.548377   0.041668       Pabe  Eukaryote -0.173249
# 675  Coding     0.304664   0.002340       Vvin  Eukaryote -0.128145
# 748  Coding     0.692730   0.011576       Anid  Eukaryote -0.249458
# 757  Coding     2.326709   0.032216       Crei  Eukaryote -0.543150
# 773  Coding     0.421459   0.031970       Lmaj  Eukaryote -0.266300
# 783  Coding     1.395087   0.020777       Ncra  Eukaryote -0.452102
# 785  Coding     0.172372   0.004030       Osat  Eukaryote -0.086700
# 787  Coding     0.120798   0.002215       Ppat  Eukaryote -0.045764
#
# [25 rows x 32 columns]
#             Biotype  DensityShuf  DensityWt         GC  \
# 105  protein_coding     0.083656   0.272446  56.011311
# 349  protein_coding     0.065614   0.175438  45.972160
# 356  protein_coding     0.061318   0.256111  53.925018
# 357  protein_coding     0.073359   0.136804  47.964103
# 358  protein_coding     0.146374   0.217691  51.564832
# 403  protein_coding     0.252839   0.494798  52.364721
# 408  protein_coding     0.086441   0.204045  53.960973
# 412  protein_coding     0.619863   0.748736  59.225824
# 415  protein_coding     0.342828   0.842679  54.086830
# 418  protein_coding     0.319676   0.601743  53.690848
# 419  protein_coding     0.172718   0.266131  51.651236
# 420  protein_coding     0.353528   0.633480  56.959741
# 421  protein_coding     0.278617   0.353413  48.356425
# 422  protein_coding     0.443857   0.599930  60.876696
# 460  protein_coding     0.002261   0.073496  38.426503
# 461  protein_coding     0.001892   0.106448  32.134887
# 467  protein_coding     0.760328   1.679478  60.937231
# 470  protein_coding     0.002407   0.119793  40.124620
# 472  protein_coding     0.036141   0.147444  41.432473
# 473  protein_coding     0.016568   0.156961  42.595241
# 475  protein_coding     0.020958   0.162349  41.397946
# 476  protein_coding     0.000000   0.563486  58.433509
# 477  protein_coding     0.006623   0.140719  37.508777
# 478  protein_coding     0.013928   0.176875  42.464340
# 481  protein_coding     0.013632   0.233280  41.117086
# 482  protein_coding     0.012845   0.079506  37.516445
# 483  protein_coding     0.020122   0.154340  40.932391
# 485  protein_coding     0.013521   0.122422  39.493065
# 489  protein_coding     0.006012   0.081868  34.141597
# 836  protein_coding     0.067839   0.226796  43.258347
# 837  protein_coding     0.022546   0.094389  40.983015
# 838  protein_coding     0.023052   0.180521  42.755143
# 839  protein_coding     0.015614   0.210872  40.276355
# 840  protein_coding     0.013010   0.156639  43.192207
# 841  protein_coding     0.112391   0.395993  47.170673
# 842  protein_coding     0.023689   0.213693  42.123396
# 844  protein_coding     0.022168   0.197035  42.597146
# 846  protein_coding     0.022174   0.166005  43.095480
#
#                                      LocID         Location  NbLocation  \
# 105              CDS-protein_coding-Coding              CDS     28633.0
# 349             exon-protein_coding-Coding             exon    195801.0
# 356             exon-protein_coding-Coding             exon     28634.0
# 357             exon-protein_coding-Coding             exon     32866.0
# 358             exon-protein_coding-Coding             exon    191612.0
# 403   five_prime_utr-protein_coding-Coding   five_prime_utr      7967.0
# 408   five_prime_utr-protein_coding-Coding   five_prime_utr     18686.0
# 412   five_prime_utr-protein_coding-Coding   five_prime_utr     29556.0
# 415   five_prime_utr-protein_coding-Coding   five_prime_utr     15747.0
# 418   five_prime_utr-protein_coding-Coding   five_prime_utr      2148.0
# 419   five_prime_utr-protein_coding-Coding   five_prime_utr     45615.0
# 420   five_prime_utr-protein_coding-Coding   five_prime_utr     30942.0
# 421   five_prime_utr-protein_coding-Coding   five_prime_utr    118089.0
# 422   five_prime_utr-protein_coding-Coding   five_prime_utr     14202.0
# 460           intron-protein_coding-Coding           intron     93110.0
# 461           intron-protein_coding-Coding           intron     64920.0
# 467           intron-protein_coding-Coding           intron    147269.0
# 470           intron-protein_coding-Coding           intron    151107.0
# 472           intron-protein_coding-Coding           intron    302696.0
# 473           intron-protein_coding-Coding           intron    223088.0
# 475           intron-protein_coding-Coding           intron    671038.0
# 476           intron-protein_coding-Coding           intron         5.0
# 477           intron-protein_coding-Coding           intron    174367.0
# 478           intron-protein_coding-Coding           intron    471486.0
# 481           intron-protein_coding-Coding           intron     29876.0
# 482           intron-protein_coding-Coding           intron    149366.0
# 483           intron-protein_coding-Coding           intron    456757.0
# 485           intron-protein_coding-Coding           intron    177988.0
# 489           intron-protein_coding-Coding           intron    107960.0
# 836  three_prime_utr-protein_coding-Coding  three_prime_utr     19398.0
# 837  three_prime_utr-protein_coding-Coding  three_prime_utr      9099.0
# 838  three_prime_utr-protein_coding-Coding  three_prime_utr     66846.0
# 839  three_prime_utr-protein_coding-Coding  three_prime_utr     12397.0
# 840  three_prime_utr-protein_coding-Coding  three_prime_utr     48003.0
# 841  three_prime_utr-protein_coding-Coding  three_prime_utr      8572.0
# 842  three_prime_utr-protein_coding-Coding  three_prime_utr      1828.0
# 844  three_prime_utr-protein_coding-Coding  three_prime_utr     22031.0
# 846  three_prime_utr-protein_coding-Coding  three_prime_utr     11841.0
#
#      NbRepro  NbTrpG4Shuf  NbTrpG4Wt  ...      nuclC      nuclG       nuclN  \
# 105        3         1160       3079  ...    4906275    4534274         0.0
# 349        3         2676       6014  ...   12677502   12819172     30911.0
# 356        3         1273       4101  ...    6896579    6286151         0.0
# 357        3          413        670  ...    1679524    1707323      5349.0
# 358        3         7379      11478  ...   16990208   17607265      2257.0
# 403        3          426        837  ...     493220     517461         0.0
# 408        3          352        829  ...    1505992    1403023    171639.0
# 412        3         2201       2511  ...    1207973    1305860       200.0
# 415        3         1026       2546  ...    1054146    1088328     11025.0
# 418        3           83        159  ...      86383      84930      2526.0
# 419        3         1347       2106  ...    2444455    2095121         2.0
# 420        3         2787       4480  ...    2594599    2685242        75.0
# 421        3         9031      11774  ...    8913498   11444969     20169.0
# 422        3         1049       1450  ...     846275     877750     14980.0
# 460        3          755       5920  ...   73503403   75211996   7969376.0
# 461        3          118       1476  ...   13605060   13570407   1351600.0
# 467        3         9956      13445  ...   11623036   12387890    564406.0
# 470        3          557       6487  ...   50757235   48766412    143957.0
# 472        3        10923      21757  ...  194647163  216421536    470259.0
# 473        3         2240       8309  ...   36822917   36193115   2637649.0
# 475        3        32053      70585  ...  928310589  972638251    748794.0
# 476        3            0          1  ...       1694       1417         0.0
# 477        3         3992      15341  ...  220391167  222346546  17628190.0
# 478        3        18124      46466  ...  545973309  563129230   2485441.0
# 481        3         1012       2572  ...   28100386   29117642   7274102.0
# 482        3          697       3427  ...   12056827   12098030      3525.0
# 483        3        16989      37422  ...  517001935  539943377  16215444.0
# 485        3         5592      13850  ...  192934734  201536265  43702700.0
# 489        3          431       3248  ...   17154115   18623232   1470715.0
# 836        3          602       2094  ...    2832829    3020875       757.0
# 837        3           55        235  ...     530746     541709         8.0
# 838        3         1374       8402  ...   14532938   14586889         0.0
# 839        3          218       2434  ...    3525926    3567793     15845.0
# 840        3          633       6009  ...   11127132   11117068         1.0
# 841        3          395       1336  ...     811686     984644         0.0
# 842        3           44        304  ...     418904     434631      1730.0
# 844        3          509       3459  ...    5481473    5529139        52.0
# 846        3          311       1769  ...    3540539    3611558     23696.0
#
#             nuclT   Class  meanShuffle stdShuffle  ShortName      Group  \
# 105  3.421545e+06  Coding     0.086715   0.002796       Ncra  Eukaryote
# 349  1.437377e+07  Coding     0.066357   0.000746       Mdom  Eukaryote
# 356  5.388556e+06  Coding     0.060227   0.001064       Ncra  Eukaryote
# 357  1.747310e+06  Coding     0.076823   0.003004       Oana  Eukaryote
# 358  1.638752e+07  Coding     0.146048   0.000568       Osat  Eukaryote
# 403  4.511450e+05  Coding     0.251026   0.006366       Acar  Eukaryote
# 408  1.154314e+06  Coding     0.087190   0.001877       Crei  Eukaryote
# 412  8.730240e+05  Coding     0.662034   0.030596       Ggal  Eukaryote
# 415  8.845260e+05  Coding     0.345799   0.006741       Mdom  Eukaryote
# 418  7.416800e+04  Coding     0.362404   0.031701       Oana  Eukaryote
# 419  2.208591e+06  Coding     0.195343   0.015950       Osat  Eukaryote
# 420  2.006796e+06  Coding     0.358179   0.004880       Ptro  Eukaryote
# 421  1.215531e+07  Coding     0.282947   0.003426       Ppat  Eukaryote
# 422  5.466920e+05  Coding     0.532240   0.051052       Pabe  Eukaryote
# 460  1.181635e+08  Coding     0.002330   0.000068       Acar  Eukaryote
# 461  2.860934e+07  Coding     0.002086   0.000180       Amel  Eukaryote
# 467  7.971089e+06  Coding     0.754926   0.003649       Crei  Eukaryote
# 470  7.529358e+07  Coding     0.002323   0.000163       Dmel  Eukaryote
# 472  3.086103e+08  Coding     0.035894   0.000226       Ggal  Eukaryote
# 473  5.031210e+07  Coding     0.016519   0.000198       Gacu  Eukaryote
# 475  1.412293e+09  Coding     0.020379   0.000455       Hsap  Eukaryote
# 476  1.282000e+03  Coding     0.000000   0.000000       Lmaj  Eukaryote
# 477  3.720715e+08  Coding     0.006612   0.000088       Mdom  Eukaryote
# 478  7.881682e+08  Coding     0.013816   0.000115       Mmus  Eukaryote
# 481  3.829507e+07  Coding     0.013791   0.000157       Oana  Eukaryote
# 482  2.211936e+07  Coding     0.012727   0.000102       Osat  Eukaryote
# 483  7.909162e+08  Coding     0.020260   0.000116       Ptro  Eukaryote
# 485  2.940231e+08  Coding     0.015327   0.000987       Pabe  Eukaryote
# 489  3.659762e+07  Coding     0.006084   0.000121       Vvin  Eukaryote
# 836  4.048733e+06  Coding     0.069234   0.001670       Ggal  Eukaryote
# 837  8.183140e+05  Coding     0.028768   0.004660       Gacu  Eukaryote
# 838  2.029902e+07  Coding     0.025051   0.001436       Hsap  Eukaryote
# 839  5.394367e+06  Coding     0.017123   0.001087       Mdom  Eukaryote
# 840  1.525219e+07  Coding     0.014402   0.000955       Mmus  Eukaryote
# 841  1.035675e+06  Coding     0.117145   0.005302       Ncra  Eukaryote
# 842  6.088180e+05  Coding     0.025661   0.002083       Oana  Eukaryote
# 844  7.752253e+06  Coding     0.023450   0.000973       Ptro  Eukaryote
# 846  4.919836e+06  Coding     0.025968   0.002197       Pabe  Eukaryote
#
#      DiffDens
# 105  0.188790
# 349  0.109825
# 356  0.194793
# 357  0.063445
# 358  0.071317
# 403  0.241959
# 408  0.117604
# 412  0.128873
# 415  0.499852
# 418  0.282067
# 419  0.093413
# 420  0.279953
# 421  0.074797
# 422  0.156074
# 460  0.071235
# 461  0.104556
# 467  0.919150
# 470  0.117386
# 472  0.111303
# 473  0.140393
# 475  0.141391
# 476  0.563486
# 477  0.134097
# 478  0.162948
# 481  0.219648
# 482  0.066662
# 483  0.134218
# 485  0.108902
# 489  0.075856
# 836  0.158957
# 837  0.071843
# 838  0.157470
# 839  0.195258
# 840  0.143630
# 841  0.283602
# 842  0.190004
# 844  0.174867
# 846  0.143830
#
# [38 rows x 32 columns]

# %% [markdown]
# - Eukrayotes -> 1 outlier, Lmaj
# - Bacteria -> 3 outlier, Tthe - Mtub - Mxan
# - Archaea -> 1 outlier, Hsal

# %%
groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    groupsLoc = group1.groupby('Location')
    for name2, group2 in groupsLoc:
        print(name1, name2)
        print('-------------'+name1+'-'+name2+'---------------')
        q75,q25 = np.percentile(group2.DiffDens,[75,25])
        intr_qr = q75-q25

        max = q75+(1.5*intr_qr)
        min = q25-(1.5*intr_qr)

        group1 = group1[group1.DiffDens > min]
        group1 = group1[group1.DiffDens < max]

        print("Correlation between pG4 Densities and GC content for "+name1)
        sns.regplot(x="GC", y="DiffDens", data=group2, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
#         plt.savefig("FiguresArticle/"+name1+"CorrelationLocation"+name2+".svg")
        plt.show()
        GC = np.array(group2["GC"])
        DensityGenes = np.array(group2["DiffDens"])
        corr1 = scipy.stats.linregress(GC, DensityGenes)
        print (corr1)
# Out:
# Archaea CDS
# -------------Archaea-CDS---------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.006923682628430057, intercept=0.2797332300307507, rvalue=-0.6329601476299113, pvalue=0.027162321518155046, stderr=0.0026779668032355123, intercept_stderr=0.1289601412031521)
# Archaea exon
# -------------Archaea-exon---------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.007163389160424732, intercept=0.2909192530622012, rvalue=-0.6465312785474057, pvalue=0.023094126842000167, stderr=0.0026729417349900283, intercept_stderr=0.12850321101343898)
# Archaea start_codon
# -------------Archaea-start_codon---------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.004111608947424822, intercept=0.09504471904236673, rvalue=-0.5378346098656496, pvalue=0.07128725407359873, stderr=0.0020380582001697863, intercept_stderr=0.09317808543129881)
# Archaea stop_codon
# -------------Archaea-stop_codon---------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.00917843624831034, intercept=0.24614081361329587, rvalue=-0.485904483264791, pvalue=0.10924650722218686, stderr=0.0052207770144002165, intercept_stderr=0.23673426130890093)
# Bacteria CDS
# -------------Bacteria-CDS---------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.0023869248056604033, intercept=0.07961166904256085, rvalue=-0.227413330223084, pvalue=0.28520457162149504, stderr=0.002179116767581457, intercept_stderr=0.10461223694778186)
# Bacteria acceptor
# -------------Bacteria-acceptor---------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0, intercept=0.0, rvalue=0.0, pvalue=1.0, stderr=0.0, intercept_stderr=0.0)
# Bacteria donor
# -------------Bacteria-donor---------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0, intercept=0.0, rvalue=0.0, pvalue=1.0, stderr=0.0, intercept_stderr=0.0)
# Bacteria exon
# -------------Bacteria-exon---------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.0023622547214999317, intercept=0.0792226738938093, rvalue=-0.22057630147406387, pvalue=0.30032369017572547, stderr=0.0022270286538729474, intercept_stderr=0.10673108632549014)
# Bacteria intron
# -------------Bacteria-intron---------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0, intercept=0.0, rvalue=0.0, pvalue=1.0, stderr=0.0, intercept_stderr=0.0)
# Bacteria junction
# -------------Bacteria-junction---------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0, intercept=0.0, rvalue=0.0, pvalue=1.0, stderr=0.0, intercept_stderr=0.0)
# Bacteria start_codon
# -------------Bacteria-start_codon---------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.005149250568989738, intercept=0.17734557351215563, rvalue=-0.7446490678620195, pvalue=3.0031743715525878e-05, stderr=0.000984019716158907, intercept_stderr=0.042986288873308305)
# Bacteria stop_codon
# -------------Bacteria-stop_codon---------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.00857646981173064, intercept=0.30910899008075404, rvalue=-0.739087815058091, pvalue=3.6989648343771974e-05, stderr=0.0016665145796128577, intercept_stderr=0.07454851851032909)
# Eukaryote CDS
# -------------Eukaryote-CDS---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.003154792374798924, intercept=0.13810934423880927, rvalue=-0.39757665460835745, pvalue=0.049056302179981116, stderr=0.0015181850304825674, intercept_stderr=0.07560679726889616)
# Eukaryote acceptor
# -------------Eukaryote-acceptor---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-5.0254997460577225e-05, intercept=0.0013327006347213306, rvalue=-0.4334366243411556, pvalue=0.030426789691419317, stderr=2.1787290734362376e-05, intercept_stderr=0.0009395755781315739)
# Eukaryote donor
# -------------Eukaryote-donor---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.00010671101798028935, intercept=-0.0036596916988074547, rvalue=0.4031579461037031, pvalue=0.04568193037484891, stderr=5.050717861350078e-05, intercept_stderr=0.0022330955223632625)
# Eukaryote exon
# -------------Eukaryote-exon---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.0018553644763129493, intercept=0.10642184288161044, rvalue=-0.22297786365385766, pvalue=0.284001952592208, stderr=0.0016913347143805134, intercept_stderr=0.08063809717249162)
# Eukaryote five_prime_utr
# -------------Eukaryote-five_prime_utr---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.007024143853801178, intercept=-0.25337145040797865, rvalue=0.504791280893753, pvalue=0.011878455651758836, stderr=0.0025609581791772654, intercept_stderr=0.12440493485671279)
# Eukaryote intron
# -------------Eukaryote-intron---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.015530180772453205, intercept=-0.4715933042338764, rvalue=0.732262323846421, pvalue=3.165344695291713e-05, stderr=0.0030116706605102794, intercept_stderr=0.11979292891715494)
# Eukaryote junction
# -------------Eukaryote-junction---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.00041933535648863777, intercept=0.01719677843203215, rvalue=-0.6453728965740946, pvalue=0.0004945090488478465, stderr=0.00010349156944869992, intercept_stderr=0.004974784108143581)
# Eukaryote start_codon
# -------------Eukaryote-start_codon---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.006367594776664741, intercept=0.2106324493302581, rvalue=-0.616893672628756, pvalue=0.0010214724785838174, stderr=0.0016939538614899924, intercept_stderr=0.08423767181159561)
# Eukaryote stop_codon
# -------------Eukaryote-stop_codon---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.009838050870107865, intercept=0.375400790997491, rvalue=-0.5545935121927231, pvalue=0.004013683811049548, stderr=0.0030779180741026487, intercept_stderr=0.13990916975029224)
# Eukaryote three_prime_utr
# -------------Eukaryote-three_prime_utr---------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.004847839723957242, intercept=-0.11403629791602544, rvalue=0.35161605426644404, pvalue=0.10856345311510933, stderr=0.0028860732958750626, intercept_stderr=0.11650047765093556)

# %% [markdown]
# # LongNC transcripts

# %%
dfNonCodingDens = pd.read_csv(path+'Results/NonCoding.csv', sep='\t')
dfNonCodingDens['ShortName'] = dfNonCodingDens.Sp.apply(applyShortName)
dfNonCodingDens['Density'] = dfNonCodingDens['DensityWt'] - dfNonCodingDens['meanShuffle']
dfNonCodingDens.head()
# Out:
#   Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 0  LongNC  LongNC     0.212585   0.106293  49.957483        3            1
# 1  LongNC  LongNC     0.019666   0.039333  50.169132        3            1
# 2  LongNC  LongNC     0.000000   0.000000  45.397490        3            0
# 3  LongNC  LongNC     0.282258   0.120968  64.915323        3            4
# 4  LongNC  LongNC     0.006139   0.006139  36.345146        3            1
#
#    NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...     Tot  nbTr     nuclA  nuclC  nuclG  \
# 0          1           2         1  ...    9408     7    2375.0   2345   2355
# 1          2           1         2  ...   50848   169   11706.0  12868  12642
# 2          0           0         0  ...     956     4     232.0    188    246
# 3          3           7         3  ...   24800    13    4190.0   8252   7847
# 4          3           3         3  ...  488709   371  139381.0  84959  92663
#
#       nuclT  ShortName  meanShuffle  stdShuffle   Density
# 0    2333.0       Apha     0.209613    0.003998 -0.103320
# 1   13632.0       Acar     0.009081    0.007293  0.030252
# 2     290.0       Amel     0.000000    0.000000  0.000000
# 3    4511.0       Aaeo     0.376118    0.128590 -0.255150
# 4  171706.0       Atha     0.010979    0.003880 -0.004840
#
# [5 rows x 23 columns]

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfNonCodingDens[dfNonCodingDens.Class == 'LongNC'])
dfTmp = dfTmp[dfTmp.Biotype == 'LongNC']
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']

my_pl = {'Eukaryote':"#D3772E", 'Eukaryotes':"#D3772E", 'Archaea':"#2686a4", 'Bacteria':"#c33543"} #test1

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.009343525511568501, intercept=0.4559047774932627, rvalue=-0.28032803472151896, pvalue=0.3774897888723465, stderr=0.010117475549215504, intercept_stderr=0.6133755595821728)
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.006863685688566623, intercept=0.2778136811356534, rvalue=-0.21572124749955937, pvalue=0.31135572521310806, stderr=0.006623771651984018, intercept_stderr=0.3516736874220613)
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.00429342866796539, intercept=0.1901304280335814, rvalue=-0.20266631137773747, pvalue=0.3312568412402386, stderr=0.004325650239126831, intercept_stderr=0.2039395929938144)

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    print(min, max)
    
    print(group1[group1.DiffDens < min])
    print(group1[group1.DiffDens > max])
# Out:
# -------------Archaea----------------
# -0.6086933379664059 0.36521600277984356
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, ShortName, meanShuffle, stdShuffle, Density, Group, DiffDens]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, ShortName, meanShuffle, stdShuffle, Density, Group, DiffDens]
# Index: []
#
# [0 rows x 25 columns]
# -------------Bacteria----------------
# -0.416159142069189 0.24969548524151342
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, ShortName, meanShuffle, stdShuffle, Density, Group, DiffDens]
# Index: []
#
# [0 rows x 25 columns]
#    Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 36  LongNC  LongNC     0.158806   0.635223  59.028109        3            1
#
#     NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...   nuclA  nuclC nuclG   nuclT  \
# 36          2           1         4  ...  1421.0   1656  2061  1159.0
#
#     ShortName  meanShuffle  stdShuffle   Density     Group  DiffDens
# 36       Mtub      0.28581       0.174  0.349413  Bacteria  0.476417
#
# [1 rows x 25 columns]
# -------------Eukaryote----------------
# -0.07497313462675874 0.12495522437793123
#    Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 15  LongNC  LongNC     0.194439   0.000000  50.281937        3            2
# 17  LongNC  LongNC     0.383939   0.060622  51.942935        3           19
# 23  LongNC  LongNC     0.345941   0.000000  51.429889        3            3
# 58  LongNC  LongNC     0.623830   0.415887  48.284467        3            3
#
#     NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...    nuclA  nuclC  nuclG    nuclT  \
# 15          0           2         0  ...   2526.0   2257   2915   2588.0
# 17          3          19         3  ...  11517.0  11455  14250  12265.0
# 23          0           3         0  ...   2038.0   2100   2360   2174.0
# 58          2           3         2  ...   1301.0   1015   1307   1186.0
#
#     ShortName  meanShuffle  stdShuffle   Density      Group  DiffDens
# 15       Crei     0.194364    0.000131 -0.194364  Eukaryote -0.194439
# 17       Drer     0.118986    0.182574 -0.058364  Eukaryote -0.323317
# 23       Ggal     0.125974    0.151499 -0.125974  Eukaryote -0.345941
# 58       Vvin     0.186968    0.301048  0.228919  Eukaryote -0.207943
#
# [4 rows x 25 columns]
#    Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 19  LongNC  LongNC     0.008087   0.140661  41.740489        3           54
# 43  LongNC  LongNC     0.000000   0.200200  50.986987        3            0
# 45  LongNC  LongNC     0.000000   0.129400  50.414079        3            0
#
#     NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...      nuclA    nuclC    nuclG  \
# 19        346          66      1148  ...  2412217.0  1703747  1702883
# 43          5           0         5  ...     6362.0     5726     7008
# 45          1           0         1  ...     1844.0     1773     2123
#
#         nuclT  ShortName  meanShuffle  stdShuffle   Density      Group  \
# 19  2342605.0       Dmel     0.008043    0.000068  0.132619  Eukaryote
# 43     5879.0       Osat     0.015333    0.048486  0.184867  Eukaryote
# 45     1888.0       Ppat     0.000000    0.000000  0.129400  Eukaryote
#
#     DiffDens
# 19  0.132574
# 43  0.200200
# 45  0.129400
#
# [3 rows x 25 columns]

# %% [markdown]
# - Eukrayotes -> 1 outlier, Lmaj
# - Bacteria -> 3 outlier, Tthe - Mtub - Mxan
# - Archaea -> 1 outlier, Hsal

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    group1 = group1[group1.DiffDens > min]
    group1 = group1[group1.DiffDens < max]
    
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/reviewCorrelation/Corr_LongNC_"+name1+".svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.009343525511568501, intercept=0.4559047774932627, rvalue=-0.28032803472151896, pvalue=0.3774897888723465, stderr=0.010117475549215504, intercept_stderr=0.6133755595821728)
# -------------Bacteria----------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.012807857909833208, intercept=0.5639171355468966, rvalue=-0.5340915305745529, pvalue=0.008662116809813826, stderr=0.00442412206658015, intercept_stderr=0.2336798010479334)
# -------------Eukaryote----------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=6.397116042608594e-05, intercept=0.016188039535329556, rvalue=0.010747918342356007, pvalue=0.9662381757054359, stderr=0.0014879035962961677, intercept_stderr=0.06879818265693058)

# %% [markdown]
# # ShortNC transcripts

# %%
dfTmp = pd.DataFrame()
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfNonCodingDens[dfNonCodingDens.Class == 'ShortNC'])
dfTmp = dfTmp[dfTmp.Biotype == 'ShortNC']
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']

my_pl = {'Eukaryote':"#D3772E", 'Eukaryotes':"#D3772E", 'Archaea':"#2686a4", 'Bacteria':"#c33543"} #test1

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
#     plt.savefig("FiguresArticle/"+name1+"CorrelationGlobal.svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=8.68571880757511e-05, intercept=-0.0566371225094821, rvalue=0.00674051802661334, pvalue=0.9834130112692251, stderr=0.004074765539409113, intercept_stderr=0.2646491246467011)
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.0014440500638299074, intercept=-0.08556136699323337, rvalue=0.07190150754394178, pvalue=0.7384758204822506, stderr=0.004270781845144215, intercept_stderr=0.2457921678045108)
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.0014909022545905256, intercept=0.07991143276949475, rvalue=-0.1899312234013296, pvalue=0.36316351783101986, stderr=0.0016069810835413335, intercept_stderr=0.0790531063828594)

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    print(min, max)
    
    print(group1[group1.DiffDens < min])
    print(group1[group1.DiffDens > max])
# Out:
# -------------Archaea----------------
# -0.27658224239441 0.16594934543664597
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, ShortName, meanShuffle, stdShuffle, Density, Group, DiffDens]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, ShortName, meanShuffle, stdShuffle, Density, Group, DiffDens]
# Index: []
#
# [0 rows x 25 columns]
# -------------Bacteria----------------
# 0.0 0.0
#     Biotype    Class  DensityShuf  DensityWt         GC  NbRepro  NbTrpG4Shuf  \
# 86  ShortNC  ShortNC     0.494756   0.197902  58.767069        3            5
# 97  ShortNC  ShortNC     0.173491   0.000000  63.272033        3            1
#
#     NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...   nuclA  nuclC nuclG   nuclT  \
# 86          2           5         2  ...  2026.0   2931  3008  2141.0
# 97          0           1         0  ...  1036.0   1747  1900  1081.0
#
#     ShortName  meanShuffle  stdShuffle   Density     Group  DiffDens
# 86       Gsul     0.371444    0.131057 -0.173541  Bacteria -0.296853
# 97       Mtub     0.257333    0.092777 -0.257333  Bacteria -0.173491
#
# [2 rows x 25 columns]
#      Biotype    Class  DensityShuf  DensityWt         GC  NbRepro  \
# 61   ShortNC  ShortNC          0.0   0.165508  56.504469        3
# 117  ShortNC  ShortNC          0.0   0.239636  67.002157        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...   nuclA  nuclC nuclG  \
# 61             0          1           0         1  ...  1319.0   1732  1682
# 117            0          2           0         2  ...  1366.0   2878  2714
#
#       nuclT  ShortName  meanShuffle  stdShuffle   Density     Group  DiffDens
# 61   1309.0       Apha     0.021114    0.051720  0.144394  Bacteria  0.165508
# 117  1388.0       Tthe     0.035575    0.087139  0.204061  Bacteria  0.239636
#
# [2 rows x 25 columns]
# -------------Eukaryote----------------
# -0.0154862688416271 0.025810448069378503
#      Biotype    Class  DensityShuf  DensityWt         GC  NbRepro  \
# 65   ShortNC  ShortNC     0.032388   0.006478  46.035355        3
# 106  ShortNC  ShortNC     0.052869   0.000000  53.062465        3
# 110  ShortNC  ShortNC     0.022625   0.000000  49.773745        3
# 119  ShortNC  ShortNC     0.046227   0.023113  50.199931        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...    nuclA  nuclC  nuclG  \
# 65             5          1           5         1  ...  38639.0  32306  38762
# 106            2          0           2         0  ...   8559.0   9337  10736
# 110            1          0           1         0  ...  10215.0   9977  12022
# 119            2          1           2         1  ...  10048.0  10115  11604
#
#        nuclT  ShortName  meanShuffle  stdShuffle   Density      Group  \
# 65   44670.0       Atha     0.015902    0.011409 -0.009425  Eukaryote
# 106   9197.0       Ppat     0.026701    0.019924 -0.026701  Eukaryote
# 110  11984.0       Scer     0.032822    0.011278 -0.032822  Eukaryote
# 119  11482.0       Vvin     0.028643    0.013392 -0.005530  Eukaryote
#
#      DiffDens
# 65  -0.025911
# 106 -0.052869
# 110 -0.022625
# 119 -0.023113
#
# [4 rows x 25 columns]
#      Biotype    Class  DensityShuf  DensityWt         GC  NbRepro  \
# 84   ShortNC  ShortNC     0.130639   0.240651  50.782802        3
# 89   ShortNC  ShortNC     0.045308   0.073190  44.939714        3
# 103  ShortNC  ShortNC     0.000000   0.046743  48.608222        3
# 105  ShortNC  ShortNC     0.026423   0.089177  45.210689        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...     nuclA   nuclC  \
# 84            19         35          19        35  ...   33360.0   34675
# 89            26         42          26        42  ...  151799.0  127193
# 103            0          2           0         2  ...   10802.0    9910
# 105           16         54          16        54  ...  160607.0  134144
#
#       nuclG     nuclT  ShortName  meanShuffle  stdShuffle   Density  \
# 84    39183   38221.0       Ggal     0.142513    0.010292  0.098138
# 89   130694  164165.0       Hsap     0.048615    0.003451  0.024575
# 103   10888   11187.0       Oana     0.025301    0.020139  0.021442
# 105  139623  171162.0       Ptro     0.046624    0.014076  0.042553
#
#          Group  DiffDens
# 84   Eukaryote  0.110012
# 89   Eukaryote  0.027882
# 103  Eukaryote  0.046743
# 105  Eukaryote  0.062754
#
# [4 rows x 25 columns]

# %%
groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print(name1)
    sns.boxplot(y="DiffDens", data=group1)
    plt.show()
# Out:
# Archaea
# Bacteria
# Eukaryote

# %% [markdown]
# - Eukrayotes -> 1 outlier, Lmaj
# - Bacteria -> 3 outlier, Tthe - Mtub - Mxan
# - Archaea -> 1 outlier, Hsal

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)

    group1 = group1[group1.DiffDens > min]
    group1 = group1[group1.DiffDens < max]
    
    if len(group1)> 3:

        print("Correlation between pG4 Densities and GC content for "+name1)
        sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
        plt.savefig("FiguresArticle/reviewCorrelation/Corr_ShortNC_"+name1+".svg")
        plt.show()
        GC = np.array(group1["GC"])
        DensityGenes = np.array(group1["DiffDens"])
#         print(group1)
#         print(GC, DensityGenes)
        corr1 = scipy.stats.linregress(GC, DensityGenes)
        print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=8.68571880757511e-05, intercept=-0.0566371225094821, rvalue=0.00674051802661334, pvalue=0.9834130112692251, stderr=0.004074765539409113, intercept_stderr=0.2646491246467011)
# -------------Bacteria----------------
# -------------Eukaryote----------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=-0.000665645715763195, intercept=0.03555605302476384, rvalue=-0.4744507608332532, pvalue=0.05432229654300835, stderr=0.00031888067965424083, intercept_stderr=0.01576721193716533)

# %% [markdown]
# # Pseudogene transcripts

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfClassCoding[dfClassCoding.Biotype == 'protein_coding'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']

my_pl = {'Eukaryote':"#D3772E", 'Eukaryotes':"#D3772E", 'Archaea':"#2686a4", 'Bacteria':"#c33543"} #test1

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
#     plt.savefig("FiguresArticle/"+name1+"CorrelationGlobal.svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.007163389160424732, intercept=0.2909192530622012, rvalue=-0.6465312785474057, pvalue=0.023094126842000167, stderr=0.0026729417349900283, intercept_stderr=0.12850321101343898)
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.002362246899414441, intercept=0.0792225005635411, rvalue=-0.2205766438413871, pvalue=0.3003229208765006, stderr=0.00222701764611345, intercept_stderr=0.1067304357961481)
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.001693721503142353, intercept=0.00335008771862233, rvalue=0.16029072951677162, pvalue=0.4440384926577824, stderr=0.002174791179367313, intercept_stderr=0.093253256148349)

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    print(min, max)
    
    print(group1[group1.DiffDens < min])
    print(group1[group1.DiffDens > max])
# Out:
# -------------Archaea----------------
# -0.24497008749483593 0.16057031050329232
#            Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  \
# 91  protein_coding  Coding     0.386796    0.08966  66.863862        3
#
#     NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...  nbTr     nuclA   nuclC  \
# 91          908        175         893       207  ...  2707  410897.0  774028
#
#      nuclG     nuclT  meanShuffle  stdShuffle  ShortName    Group  DiffDens
# 91  769664  354120.0     0.388224    0.016229       Hsal  Archaea -0.297136
#
# [1 rows x 24 columns]
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, meanShuffle, stdShuffle, ShortName, Group, DiffDens]
# Index: []
#
# [0 rows x 24 columns]
# -------------Bacteria----------------
# -0.15452363115961057 0.08850673691072845
#             Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  \
# 100  protein_coding  Coding     0.428506   0.138196  65.932531        3
# 102  protein_coding  Coding     0.556553   0.191741  69.164211        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...  nbTr      nuclA  \
# 100         1719        300        1724       556  ...  4018   674151.0
# 102         3826       1279        4650      1602  ...  7331  1281502.0
#
#        nuclC    nuclG      nuclT  meanShuffle  stdShuffle  ShortName  \
# 100  1298856  1353793   696478.0     0.431546    0.006843       Mtub
# 102  2825308  2953366  1294830.0     0.558658    0.002625       Mxan
#
#         Group  DiffDens
# 100  Bacteria -0.290311
# 102  Bacteria -0.364811
#
# [2 rows x 24 columns]
#             Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  \
# 120  protein_coding  Coding     0.398602   0.785246  69.708796        3
#
#      NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...  nbTr     nuclA  \
# 120         1016       1059         800      1576  ...  2238  295103.0
#
#       nuclC   nuclG     nuclT  meanShuffle  stdShuffle  ShortName     Group  \
# 120  706692  692374  312842.0     0.415648    0.011865       Tthe  Bacteria
#
#      DiffDens
# 120  0.386644
#
# [1 rows x 24 columns]
# -------------Eukaryote----------------
# -0.1694869041966995 0.3108225066414765
#            Biotype   Class  DensityShuf  DensityWt         GC  NbRepro  \
# 95  protein_coding  Coding     0.241818   0.072163  62.468798        3
#
#     NbTrpG4Shuf  NbTrpG4Wt  NbpG4rShuf  NbpG4rWt  ...  nbTr      nuclA  \
# 95         3597        972        3800      1134  ...  8315  3029798.0
#
#       nuclC    nuclG      nuclT  meanShuffle  stdShuffle  ShortName  \
# 95  4869112  4947436  2867974.0     0.238044    0.004357       Lmaj
#
#         Group  DiffDens
# 95  Eukaryote -0.169654
#
# [1 rows x 24 columns]
# Empty DataFrame
# Columns: [Biotype, Class, DensityShuf, DensityWt, GC, NbRepro, NbTrpG4Shuf, NbTrpG4Wt, NbpG4rShuf, NbpG4rWt, PercentShuf, PercentWt, Sp, Tot, nbTr, nuclA, nuclC, nuclG, nuclT, meanShuffle, stdShuffle, ShortName, Group, DiffDens]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# - Eukrayotes -> 1 outlier, Lmaj
# - Bacteria -> 3 outlier, Tthe - Mtub - Mxan
# - Archaea -> 1 outlier, Hsal

# %%
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    group1 = group1[group1.DiffDens > min]
    group1 = group1[group1.DiffDens < max]
    
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="GC", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/reviewCorrelation/Corr_Pseudogene_"+name1+".svg")
    plt.show()
    GC = np.array(group1["GC"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.004112732546290351, intercept=0.16289444434067946, rvalue=-0.4073573301505278, pvalue=0.21367740362673357, stderr=0.0030734936910097694, intercept_stderr=0.14134533882172073)
# -------------Bacteria----------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=-0.002581705912564568, intercept=0.08979764371133331, rvalue=-0.6440887072268058, pvalue=0.0016265636814176215, stderr=0.0007034249871222002, intercept_stderr=0.031132064074624457)
# -------------Eukaryote----------------
# Correlation between pG4 Densities and GC content for Eukaryote
# LinregressResult(slope=0.006361151521473588, intercept=-0.1774628290599356, rvalue=0.6336546265876492, pvalue=0.0008863297277250736, stderr=0.0016557595515439573, intercept_stderr=0.06931752301711437)

# %% [markdown]
# # Boxplot sp vs sp

# %%
def f_test(x, y):
    x = np.array(x)
    y = np.array(y)
    f = np.var(x, ddof=1)/np.var(y, ddof=1) #calculate F test statistic 
    dfn = x.size-1 #define degrees of freedom numerator 
    dfd = y.size-1 #define degrees of freedom denominator 
    p = 1-scipy.stats.f.cdf(f, dfn, dfd) #find p-value of F test statistic 
    return f, p

def AllTest(a,b,alpha, name1, name2):
    if len(a) >= 3 and len(b) >= 3:
        shapA = scipy.stats.shapiro(a)
        shapB = scipy.stats.shapiro(b)

        if shapA[1] > alpha and shapB[1] > alpha:
            print("\tFisher test")
            f = f_test(a, b)
            if f[1] > alpha:
                print("\tt test")
                tTest =scipy.stats.ttest_ind(a,b)
                if tTest[1] <= alpha:
                    print("Means are significatly different")
                else:
                    print("Means are not differents")
                return(tTest)
            else:
                print("\twelch test")
                welch = scipy.stats.ttest_ind(a,b, equal_var=False)
                if welch[1] <= alpha:
                    print("Means are significatly different")
                else:
                    print("Means are not differents")
                return(welch)
        else:
            print("\tmannwhitneyu test")
            man = scipy.stats.mannwhitneyu(a,b)
            if man[1] <= alpha:
                print("Means are significatly different")
            else:
                print("Means are not differents")
            return(man)
    else:
        print('There are only 3 data for '+name1+' of '+name2+' transcripts.')
        return []
        
def makeBoxPlotSpvsSp(resTest, df, alpha, typeDens, listGrp, cl):
    if typeDens:
        if 'Shuf' in typeDens:
            my_pal = {}
            for grp in listGrp:
                my_pal[grp] = "#E64E46"
        else:
            my_pal = {}
            for grp in listGrp:
                my_pal[grp] = "#73BCAA"
    else:
        typeDens = 'DiffDens'
        my_pal = {}
        paletteSp = {'Eukaryote': '#D3772E', 'Archaea' : '#2686a4', 'Bacteria' : '#c33543'}
        for grp in listGrp:
            my_pal[grp] = paletteSp[grp]
    if resTest > alpha:
        sns.boxplot(x="Group", y=typeDens, data=df, palette=my_pal)
        plt.title("Densities of "+'/'.join(listGrp)+" for "+cl+" transcripts classe", loc='left')
        plt.savefig("FiguresArticle/"+"-".join(listGrp)+"_boxplot_"+cl+"_transcriptSp.svg")
        plt.show()
    else:
        sns.boxplot(x="Group", y=typeDens, data=df, palette=my_pal)
        plt.title("Densities for "+'/'.join(listGrp)+" for "+cl+" transcripts classe", loc='left')
        # statistical annotation
        x1, x2 = 0, 1   # columns 'Sat' and 'Sun' (first column: 0, see plt.xticks())
        y, h, col = df[typeDens].max() + 0.25, 0.25, 'k'
        plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
        plt.savefig("FiguresArticle/"+"-".join(listGrp)+"_boxplot_"+cl+"_transcriptSp.svg")
        plt.show()

# %% [markdown]
# ## Global

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfGlobal[dfGlobal.Class == 'Global'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']
spList = [ ['Eukaryote', 'Archaea'], ['Eukaryote', 'Bacteria'], ['Archaea', 'Bacteria'] ]

for duoSp in spList:
    
    a = dfTmp[dfTmp.Group == duoSp[0] ]['DiffDens']
    b = dfTmp[dfTmp.Group == duoSp[1] ]['DiffDens']
    
    q75,q25 = np.percentile(a,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    a = a[a > min]
    a = a[a < max]
    
    q75,q25 = np.percentile(b,[75,25])
    intr_qr = q75-q25
    
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    b = b[b > min]
    b = b[b < max]

    res = AllTest(a,b,0.05, name2, '/'.join(duoSp))

    dfTmp2 = pd.DataFrame()
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[0] ])
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[1] ])

    if res != []:
        print(res)
        makeBoxPlotSpvsSp(res[1], dfTmp2, 0.05, None, duoSp, 'Global')
# Out:
# 	Fisher test
# 	t test
# Means are significatly different
# Ttest_indResult(statistic=3.7945758655948496, pvalue=0.0006003954161916735)
# 	mannwhitneyu test
# Means are significatly different
# MannwhitneyuResult(statistic=489.0, pvalue=7.425394611669623e-08)
# 	mannwhitneyu test
# Means are not differents
# MannwhitneyuResult(statistic=134.0, pvalue=0.4751235238172632)

# %% [markdown]
# ## Coding

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfClassCoding[dfClassCoding.Biotype == 'protein_coding'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']
spList = [ ['Eukaryote', 'Archaea'], ['Eukaryote', 'Bacteria'], ['Archaea', 'Bacteria'] ]

for duoSp in spList:
    
    a = dfTmp[dfTmp.Group == duoSp[0] ]['DiffDens']
    b = dfTmp[dfTmp.Group == duoSp[1] ]['DiffDens']
    
    q75,q25 = np.percentile(a,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    a = a[a > min]
    a = a[a < max]
    
    q75,q25 = np.percentile(b,[75,25])
    intr_qr = q75-q25
    
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    b = b[b > min]
    b = b[b < max]

    res = AllTest(a,b,0.05, name2, '/'.join(duoSp))

    dfTmp2 = pd.DataFrame()
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[0] ])
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[1] ])

    if res != []:
        print(res)
        makeBoxPlotSpvsSp(res[1], dfTmp2, 0.05, None, duoSp, 'Coding')
# Out:
# 	Fisher test
# 	t test
# Means are significatly different
# Ttest_indResult(statistic=3.7426068318572647, pvalue=0.0006941748020705211)
# 	mannwhitneyu test
# Means are significatly different
# MannwhitneyuResult(statistic=480.0, pvalue=2.2693133282320644e-07)
# 	mannwhitneyu test
# Means are not differents
# MannwhitneyuResult(statistic=137.0, pvalue=0.4047344344781626)

# %% [markdown]
# ## LongNC

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfNonCodingDens[dfNonCodingDens.Class == 'LongNC'])
dfTmp = dfTmp[dfTmp.Biotype == 'LongNC']
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']
spList = [ ['Eukaryote', 'Archaea'], ['Eukaryote', 'Bacteria'], ['Archaea', 'Bacteria'] ]

for duoSp in spList:
    
    a = dfTmp[dfTmp.Group == duoSp[0] ]['DiffDens']
    b = dfTmp[dfTmp.Group == duoSp[1] ]['DiffDens']
    
    q75,q25 = np.percentile(a,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    a = a[a > min]
    a = a[a < max]
    
    q75,q25 = np.percentile(b,[75,25])
    intr_qr = q75-q25
    
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    b = b[b > min]
    b = b[b < max]

    res = AllTest(a,b,0.05, name2, '/'.join(duoSp))

    dfTmp2 = pd.DataFrame()
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[0] ])
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[1] ])

    if res != []:
        print(res)
        makeBoxPlotSpvsSp(res[1], dfTmp2, 0.05, None, duoSp, 'LongNC')
# Out:
# 	mannwhitneyu test
# Means are significatly different
# MannwhitneyuResult(statistic=163.5, pvalue=0.017678545992184727)
# 	mannwhitneyu test
# Means are significatly different
# MannwhitneyuResult(statistic=355.0, pvalue=7.097608322993962e-05)
# 	mannwhitneyu test
# Means are not differents
# MannwhitneyuResult(statistic=139.0, pvalue=0.9859178681210062)

# %% [markdown]
# ## ShortNC

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfNonCodingDens[dfNonCodingDens.Class == 'ShortNC'])
dfTmp = dfTmp[dfTmp.Biotype == 'ShortNC']
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']
spList = [ ['Eukaryote', 'Archaea'], ['Eukaryote', 'Bacteria'], ['Archaea', 'Bacteria'] ]

for duoSp in spList:
    
    a = dfTmp[dfTmp.Group == duoSp[0] ]['DiffDens']
    b = dfTmp[dfTmp.Group == duoSp[1] ]['DiffDens']
    
    q75,q25 = np.percentile(a,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    a = a[a > min]
    a = a[a < max]
    
    q75,q25 = np.percentile(b,[75,25])
    intr_qr = q75-q25
    
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    b = b[b > min]
    b = b[b < max]

    res = AllTest(a,b,0.05, name2, '/'.join(duoSp))

    dfTmp2 = pd.DataFrame()
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[0] ])
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[1] ])

    if res != []:
        print(res)
        makeBoxPlotSpvsSp(res[1], dfTmp2, 0.05, None, duoSp, 'ShortNC')
# Out:
# 	mannwhitneyu test
# Means are significatly different
# MannwhitneyuResult(statistic=165.5, pvalue=0.0022322487048677003)
# There are only 3 data for three_prime_utr of Eukaryote/Bacteria transcripts.
# There are only 3 data for three_prime_utr of Archaea/Bacteria transcripts.

# %% [markdown]
# ## Pseudogene

# %%
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfGlobal[dfGlobal.Class == 'Global'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp['ShortName'] = dfTmp.Sp.apply(applyShortName)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']
spList = [ ['Eukaryote', 'Archaea'], ['Eukaryote', 'Bacteria'], ['Archaea', 'Bacteria'] ]

for duoSp in spList:
    
    a = dfTmp[dfTmp.Group == duoSp[0] ]['DiffDens']
    b = dfTmp[dfTmp.Group == duoSp[1] ]['DiffDens']
    
    q75,q25 = np.percentile(a,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    a = a[a > min]
    a = a[a < max]
    
    q75,q25 = np.percentile(b,[75,25])
    intr_qr = q75-q25
    
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    b = b[b > min]
    b = b[b < max]

    res = AllTest(a,b,0.05, name2, '/'.join(duoSp))

    dfTmp2 = pd.DataFrame()
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[0] ])
    dfTmp2 = dfTmp2.append(dfTmp[dfTmp.Group == duoSp[1] ])

    if res != []:
        print(res)
        makeBoxPlotSpvsSp(res[1], dfTmp2, 0.05, None, duoSp, 'Pseudogene')
# Out:
# 	Fisher test
# 	t test
# Means are significatly different
# Ttest_indResult(statistic=3.7945758655948496, pvalue=0.0006003954161916735)
# 	mannwhitneyu test
# Means are significatly different
# MannwhitneyuResult(statistic=489.0, pvalue=7.425394611669623e-08)
# 	mannwhitneyu test
# Means are not differents
# MannwhitneyuResult(statistic=134.0, pvalue=0.4751235238172632)

# %% [markdown]
# # Temperature

# %%
def getdicoTemp():
    d = {'methanosarcina_acetivorans_c2a' : 35,
    'halobacterium_salinarum_r1' : 37,
    'hyperthermus_butylicus_dsm_5456' : 107,
    'archaeoglobus_fulgidus_dsm_4304' : 75,
    'methanobrevibacter_smithii_atcc_35061' : 37,
    'pyrococcus_horikoshii_ot3' : 98,
    'thermoplasma_acidophilum_dsm_1728' : 59,
    'sulfolobus_solfataricus_p2' : 80,
    'pyrobaculum_aerophilum_str_im2' : 60,
    'nanoarchaeum_equitans_kin4_m' : 80,
    'candidatus_korarchaeum_cryptofilum_opf8' : 70,
    'cenarchaeum_symbiosum_a' : -5,
    'aquifex_aeolicus_vf5' : 85,
    'mycoplasma_pneumoniae_m129' : 37,
    'staphylococcus_aureus_subsp_aureus_n315' : 37,
    'bacillus_subtilis_subsp_subtilis_str_168' : 37,
    'enterococcus_faecalis_v583' : 37,
    'streptococcus_pneumoniae_tigr4' : 37,
    'chloroflexus_aurantiacus_j_10_fl' : 55,
    'mycobacterium_tuberculosis_h37rv' : 37,
    'thermus_thermophilus_hb8' : 65,
    'chlamydia_trachomatis_d_uw_3_cx' : 37,
    'borrelia_burgdorferi_b31' : 37,
    'campylobacter_jejuni_subsp_jejuni_nctc_11168_atcc_700819' : 37,
    'myxococcus_xanthus_dk_1622' : 36,
    'geobacter_sulfurreducens_pca' : 35,
    'wolbachia_endosymbiont_of_drosophila_melanogaster' : 34,
    'anaplasma_phagocytophilum_str_hz' : 37,
    'brucella_abortus_bv_1_str_9_941' : 35,
    'neisseria_meningitidis_z2491' : 37,
    'legionella_pneumophila_str_paris' : 37,
    'francisella_tularensis_subsp_tularensis_schu_s4' : 36,
    'vibrio_cholerae_o1_biovar_el_tor_str_n16961' : 37,
    'haemophilus_influenzae_rd_kw20' : 37,
    'yersinia_pestis_biovar_microtus_str_91001' : 37,
    'escherichia_coli_str_k_12_substr_mg1655' : 37}
    return d

def getTemp(sp):
    d = getdicoTemp()
    return d[sp]

# %%
# TEMPERATURE
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfClassCoding[dfClassCoding.Biotype == 'protein_coding'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp = dfTmp[dfTmp.Group != 'Eukaryote']
dfTmp['Temp'] = dfTmp.Sp.apply(getTemp)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']

del dfTmp['PercentShuf']
del dfTmp['nuclC']
del dfTmp['nbTr']
del dfTmp['NbpG4rWt']
del dfTmp['NbpG4rShuf']
del dfTmp['NbTrpG4Wt']
del dfTmp['NbTrpG4Shuf']
del dfTmp['Tot']
del dfTmp['nuclG']
del dfTmp['PercentWt']
dfTmp = dfTmp.drop_duplicates(subset=None, keep='first', inplace=False)

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    group1 = group1[group1.DiffDens > min]
    group1 = group1[group1.DiffDens < max]
    
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="Temp", y="DiffDens", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/reviewCorrelation/Corr_Dens-Temp_"+name1+".svg")
    plt.show()
    GC = np.array(group1["Temp"])
    DensityGenes = np.array(group1["DiffDens"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=0.00048680726342905766, intercept=-0.053872496343965084, rvalue=0.17365728066311534, pvalue=0.6095960541759213, stderr=0.0009202239875760398, intercept_stderr=0.06452195501276993)
# -------------Bacteria----------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=2.1138929023404182e-05, intercept=-0.022931441523332315, rvalue=0.006395654253764271, pvalue=0.9780497365447819, stderr=0.0007582498266288952, intercept_stderr=0.031257748516479944)

# %%
# TEMPERATURE
dfTmp = pd.DataFrame()
dfTmp = dfTmp.append(dfClassCoding[dfClassCoding.Biotype == 'protein_coding'])
dfTmp['Group'] = dfTmp.Sp.apply(getGrp)
dfTmp = dfTmp[dfTmp.Group != 'Eukaryote']
dfTmp['Temp'] = dfTmp.Sp.apply(getTemp)
dfTmp['DiffDens'] = dfTmp['DensityWt'] - dfTmp['DensityShuf']

del dfTmp['PercentShuf']
del dfTmp['nuclC']
del dfTmp['nbTr']
del dfTmp['NbpG4rWt']
del dfTmp['NbpG4rShuf']
del dfTmp['NbTrpG4Wt']
del dfTmp['NbTrpG4Shuf']
del dfTmp['Tot']
del dfTmp['nuclG']
del dfTmp['PercentWt']
dfTmp = dfTmp.drop_duplicates(subset=None, keep='first', inplace=False)

groupsSp = dfTmp.groupby('Group')
for name1, group1 in groupsSp:
    print('-------------'+name1+'----------------')
    q75,q25 = np.percentile(group1.DiffDens,[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    
    group1 = group1[group1.DiffDens > min]
    group1 = group1[group1.DiffDens < max]
    
    print("Correlation between pG4 Densities and GC content for "+name1)
    sns.regplot(x="Temp", y="GC", data=group1, scatter_kws={"color": my_pl[name1]}, line_kws={"color": my_pl[name1]})
    plt.savefig("FiguresArticle/reviewCorrelation/Corr_GC-Temp_"+name1+".svg")
    plt.show()
    GC = np.array(group1["Temp"])
    DensityGenes = np.array(group1["GC"])
    corr1 = scipy.stats.linregress(GC, DensityGenes)
    print (corr1)
# Out:
# -------------Archaea----------------
# Correlation between pG4 Densities and GC content for Archaea
# LinregressResult(slope=-0.05545870404423439, intercept=48.72599669161697, rvalue=-0.19973795344285875, pvalue=0.5559744142083112, stderr=0.09068744690821726, intercept_stderr=6.358594699370896)
# -------------Bacteria----------------
# Correlation between pG4 Densities and GC content for Bacteria
# LinregressResult(slope=0.09231210457431466, intercept=39.668498223554806, rvalue=0.1119493907272203, pvalue=0.6290059682865881, stderr=0.18798425969438087, intercept_stderr=7.749378250051939)
